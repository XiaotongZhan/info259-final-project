# %%
# ============ Set Seed ============
def set_seed(seed=42):
    # Set random seed for reproducibility across libraries
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)

# ============ Dataset ============
class Twitter15Dataset(Dataset):
    def __init__(self, graph_data_list):
        """
        Custom PyTorch Dataset for Twitter15 graph data.
        Each graph is a dictionary containing 'x' (features),
        'edge_index' (graph connectivity), and 'y' (label).
        """
        self.graphs = graph_data_list

    def __len__(self):
        return len(self.graphs)

    def __getitem__(self, idx):
        graph = self.graphs[idx]
        x = graph['x']
        edge_index = graph['edge_index']
        y = graph['y']
        return x, edge_index, y

def collate_fn(batch):
    """
    Custom collate function for batching variable-length graph data.
    Pads node features and masks them appropriately. Also offsets edge indices.
    """
    xs, edge_indices, ys = zip(*batch)
    max_len = max(x.shape[0] for x in xs)
    feature_dim = xs[0].shape[1]

    padded_xs, masks, edge_indices_new = [], [], []

    for i, (x, edge_index) in enumerate(zip(xs, edge_indices)):
        seq_len = x.shape[0]
        pad_len = max_len - seq_len

        # Pad the node features
        x_padded = torch.cat([x, torch.zeros((pad_len, feature_dim), dtype=x.dtype)], dim=0) if pad_len > 0 else x

        # Mask indicating valid node positions
        mask = torch.cat([torch.ones(seq_len), torch.zeros(pad_len)]).bool()

        # Offset edge indices to avoid overlap across graphs in batch
        edge_index_offset = edge_index.clone()
        edge_index_offset += i * max_len

        padded_xs.append(x_padded)
        masks.append(mask)
        edge_indices_new.append(edge_index_offset)

    return (
        torch.stack(padded_xs),
        torch.stack(masks),
        torch.cat(edge_indices_new, dim=1),
        torch.tensor(ys)
    )

# ============ Model ============

# GCN-based encoder for graph structure
class GraphEncoder(nn.Module):
    def __init__(self, hidden_dim):
        super().__init__()
        self.gcn = GCNConv(hidden_dim, hidden_dim)

    def forward(self, x, mask, edge_index):
        B, L, D = x.size()
        x_flat = x.view(B * L, D)

        # Apply mask before GCN
        mask_flat = mask.view(B * L).unsqueeze(-1).to(x.dtype)
        x_flat = x_flat * mask_flat

        # Run GCN if graph has edges
        h_flat = self.gcn(x_flat, edge_index) if edge_index.numel() > 0 else x_flat

        # Apply mask after GCN
        h_flat = h_flat * mask_flat
        return h_flat.view(B, L, D)

# Wrapper for a single Mamba layer with dropout
class MambaLayer(nn.Module):
    def __init__(self, hidden_dim, dropout_rate):
        super().__init__()
        self.mamba = Mamba(d_model=hidden_dim)
        self.dropout = nn.Dropout(dropout_rate)

    def forward(self, x):
        return self.dropout(self.mamba(x))

# Stacked Mamba-based encoder
class MambaEncoder(nn.Module):
    def __init__(self, input_dim=833, hidden_dim=128, num_layers=2, dropout_rate=0.2):
        super().__init__()
        self.input_proj = nn.Linear(input_dim, hidden_dim)
        self.layers = nn.ModuleList([
            MambaLayer(hidden_dim, dropout_rate) for _ in range(num_layers)
        ])
        self.norm = nn.LayerNorm(hidden_dim)

    def forward(self, x, mask):
        x = self.input_proj(x)
        mask_f = mask.unsqueeze(-1).to(x.dtype)
        x = x * mask_f

        for layer in self.layers:
            x = layer(x)
            x = x * mask_f

        return self.norm(x)

# Mean pooling over masked sequences
class MeanPooling(nn.Module):
    def forward(self, x, mask):
        mask = mask.unsqueeze(-1)
        x = x * mask
        sum_x = x.sum(dim=1)
        lengths = mask.sum(dim=1)
        return sum_x / lengths.clamp(min=1e-6)

# Classification head with ReLU nonlinearity
class ClassifierHead(nn.Module):
    def __init__(self, hidden_dim=128, num_classes=4):
        super().__init__()
        self.fc = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, num_classes)
        )

    def forward(self, x):
        return self.fc(x)

# Combined model: Mamba + GNN + Pooling + Classification
class MambaClassifier(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, num_classes):
        super().__init__()
        self.norm = nn.LayerNorm(input_dim)
        self.encoder = MambaEncoder(input_dim, hidden_dim, num_layers)
        self.gnn_encoder = GraphEncoder(hidden_dim)
        self.pooling = MeanPooling()
        self.classifier = ClassifierHead(hidden_dim, num_classes)

    def forward(self, x, mask, edge_index):
        x = self.norm(x)
        h_seq = self.encoder(x, mask)
        h_graph = self.gnn_encoder(h_seq, mask, edge_index)
        h = h_seq + 0.3 * h_graph  # Combine sequence and graph features
        pooled = self.pooling(h, mask)
        logits = self.classifier(pooled)
        return torch.clamp(logits, min=-10, max=10)  # Avoid extreme values

# ============ Loss Function ============

# Label smoothing cross-entropy loss
def smooth_cross_entropy(preds, targets, smoothing=0.1):
    confidence = 1.0 - smoothing
    logprobs = F.log_softmax(preds, dim=-1)
    nll_loss = -logprobs.gather(dim=-1, index=targets.unsqueeze(1)).squeeze(1)
    smooth_loss = -logprobs.mean(dim=-1)
    return (confidence * nll_loss + smoothing * smooth_loss).mean()

# ============ Training & Evaluation ============

# One training epoch
def train_one_epoch(model, train_loader, optimizer, loss_fn, device):
    model.train()
    running_loss = 0.0
    all_preds, all_labels = [], []

    for x, mask, edge_index, y in train_loader:
        x, mask, y = x.to(device), mask.to(device), y.to(device)
        edge_index = edge_index.to(device)
        x = torch.nan_to_num(x, nan=0.0)  # Replace NaNs

        optimizer.zero_grad()
        logits = model(x, mask, edge_index)

        # Skip unstable batches
        if torch.isnan(logits).any() or torch.isinf(logits).any():
            continue

        loss = loss_fn(logits, y)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()

        running_loss += loss.item() * x.size(0)
        all_preds.extend(logits.argmax(dim=-1).detach().cpu().tolist())
        all_labels.extend(y.cpu().tolist())

    avg_loss = running_loss / len(train_loader.dataset)
    acc = accuracy_score(all_labels, all_preds)
    f1 = f1_score(all_labels, all_preds, average='macro')
    return avg_loss, acc, f1

# One evaluation epoch
def evaluate_one_epoch(model, val_loader, loss_fn, device):
    model.eval()
    running_loss = 0.0
    all_preds, all_labels = [], []

    with torch.no_grad():
        for x, mask, edge_index, y in val_loader:
            x, mask, y = x.to(device), mask.to(device), y.to(device)
            edge_index = edge_index.to(device)

            logits = model(x, mask, edge_index)
            if torch.isnan(logits).any() or torch.isinf(logits).any():
                continue

            loss = loss_fn(logits, y)
            running_loss += loss.item() * x.size(0)

            all_preds.extend(logits.argmax(dim=-1).cpu().tolist())
            all_labels.extend(y.cpu().tolist())

    avg_loss = running_loss / len(val_loader.dataset)
    acc = accuracy_score(all_labels, all_preds)
    f1 = f1_score(all_labels, all_preds, average='macro')
    return avg_loss, acc, f1
# Out:
# Train: 1043, Val: 223, Test: 224
#
# >>> Trying lr=5e-05, weight_decay=0.01
# Epoch 1:
#   Train Loss: 1.3845 | Train Acc: 0.2464 | Train F1: 0.2141
#   Val   Loss: 1.1884 | Val   Acc: 0.2199 | Val   F1: 0.1512
# Epoch 2:
#   Train Loss: 1.3704 | Train Acc: 0.3471 | Train F1: 0.2692
#   Val   Loss: 1.1761 | Val   Acc: 0.3141 | Val   F1: 0.2520
# Epoch 3:
#   Train Loss: 1.3353 | Train Acc: 0.4056 | Train F1: 0.3327
#   Val   Loss: 1.1536 | Val   Acc: 0.3665 | Val   F1: 0.2914
# Epoch 4:
#   Train Loss: 1.2873 | Train Acc: 0.4305 | Train F1: 0.3763
#   Val   Loss: 1.1464 | Val   Acc: 0.3770 | Val   F1: 0.3376
# Epoch 5:
#   Train Loss: 1.2409 | Train Acc: 0.4823 | Train F1: 0.4603
#   Val   Loss: 1.1147 | Val   Acc: 0.4084 | Val   F1: 0.3709
# Epoch 6:
#   Train Loss: 1.1909 | Train Acc: 0.5340 | Train F1: 0.5169
#   Val   Loss: 1.1148 | Val   Acc: 0.4450 | Val   F1: 0.4124
# Epoch 7:
#   Train Loss: 1.1407 | Train Acc: 0.5427 | Train F1: 0.5159
#   Val   Loss: 1.1565 | Val   Acc: 0.4084 | Val   F1: 0.4078
# EarlyStopping counter: 1 out of 10
# Epoch 8:
#   Train Loss: 1.1094 | Train Acc: 0.5791 | Train F1: 0.5657
#   Val   Loss: 1.1288 | Val   Acc: 0.4555 | Val   F1: 0.4417
# Epoch 9:
#   Train Loss: 1.0596 | Train Acc: 0.6165 | Train F1: 0.6056
#   Val   Loss: 1.1280 | Val   Acc: 0.4660 | Val   F1: 0.4563
# Epoch 10:
#   Train Loss: 1.0249 | Train Acc: 0.6433 | Train F1: 0.6334
#   Val   Loss: 1.1244 | Val   Acc: 0.4712 | Val   F1: 0.4575
# Epoch 11:
#   Train Loss: 0.9842 | Train Acc: 0.6692 | Train F1: 0.6581
#   Val   Loss: 1.0918 | Val   Acc: 0.4817 | Val   F1: 0.4781
# Epoch 12:
#   Train Loss: 0.9466 | Train Acc: 0.6836 | Train F1: 0.6731
#   Val   Loss: 1.1288 | Val   Acc: 0.4503 | Val   F1: 0.4491
# EarlyStopping counter: 1 out of 10
# Epoch 13:
#   Train Loss: 0.9235 | Train Acc: 0.6951 | Train F1: 0.6886
#   Val   Loss: 1.0766 | Val   Acc: 0.4974 | Val   F1: 0.4905
# Epoch 14:
#   Train Loss: 0.8845 | Train Acc: 0.7392 | Train F1: 0.7350
#   Val   Loss: 1.1418 | Val   Acc: 0.4555 | Val   F1: 0.4555
# EarlyStopping counter: 1 out of 10
# Epoch 15:
#   Train Loss: 0.8721 | Train Acc: 0.7306 | Train F1: 0.7242
#   Val   Loss: 1.1085 | Val   Acc: 0.5079 | Val   F1: 0.5049
# Epoch 16:
#   Train Loss: 0.8360 | Train Acc: 0.7478 | Train F1: 0.7417
#   Val   Loss: 1.0851 | Val   Acc: 0.5131 | Val   F1: 0.5133
# Epoch 17:
#   Train Loss: 0.8070 | Train Acc: 0.7824 | Train F1: 0.7797
#   Val   Loss: 1.0864 | Val   Acc: 0.5340 | Val   F1: 0.5311
# Epoch 18:
#   Train Loss: 0.7849 | Train Acc: 0.7948 | Train F1: 0.7931
#   Val   Loss: 1.1335 | Val   Acc: 0.5131 | Val   F1: 0.5142
# EarlyStopping counter: 1 out of 10
# Epoch 19:
#   Train Loss: 0.7630 | Train Acc: 0.7987 | Train F1: 0.7963
#   Val   Loss: 1.0842 | Val   Acc: 0.5079 | Val   F1: 0.5087
# EarlyStopping counter: 2 out of 10
# Epoch 20:
#   Train Loss: 0.7490 | Train Acc: 0.8073 | Train F1: 0.8064
#   Val   Loss: 1.1145 | Val   Acc: 0.5497 | Val   F1: 0.5502
# Epoch 21:
#   Train Loss: 0.7197 | Train Acc: 0.8207 | Train F1: 0.8200
#   Val   Loss: 1.1285 | Val   Acc: 0.5393 | Val   F1: 0.5400
# EarlyStopping counter: 1 out of 10
# Epoch 22:
#   Train Loss: 0.6975 | Train Acc: 0.8456 | Train F1: 0.8451
#   Val   Loss: 1.1045 | Val   Acc: 0.5654 | Val   F1: 0.5553
# Epoch 23:
#   Train Loss: 0.6919 | Train Acc: 0.8341 | Train F1: 0.8334
#   Val   Loss: 1.1127 | Val   Acc: 0.5759 | Val   F1: 0.5629
# Epoch 24:
#   Train Loss: 0.6647 | Train Acc: 0.8571 | Train F1: 0.8567
#   Val   Loss: 1.1165 | Val   Acc: 0.5602 | Val   F1: 0.5588
# EarlyStopping counter: 1 out of 10
# Epoch 25:
#   Train Loss: 0.6506 | Train Acc: 0.8562 | Train F1: 0.8558
#   Val   Loss: 1.1015 | Val   Acc: 0.5759 | Val   F1: 0.5709
# Epoch 26:
#   Train Loss: 0.6201 | Train Acc: 0.8821 | Train F1: 0.8816
#   Val   Loss: 1.1057 | Val   Acc: 0.5969 | Val   F1: 0.5891
# Epoch 27:
#   Train Loss: 0.6143 | Train Acc: 0.8754 | Train F1: 0.8750
#   Val   Loss: 1.0858 | Val   Acc: 0.6073 | Val   F1: 0.5985
# Epoch 28:
#   Train Loss: 0.5946 | Train Acc: 0.8965 | Train F1: 0.8963
#   Val   Loss: 1.1129 | Val   Acc: 0.6021 | Val   F1: 0.5944
# EarlyStopping counter: 1 out of 10
# Epoch 29:
#   Train Loss: 0.5835 | Train Acc: 0.8936 | Train F1: 0.8935
#   Val   Loss: 1.1141 | Val   Acc: 0.5916 | Val   F1: 0.5870
# EarlyStopping counter: 2 out of 10
# Epoch 30:
#   Train Loss: 0.5675 | Train Acc: 0.9070 | Train F1: 0.9064
#   Val   Loss: 1.1067 | Val   Acc: 0.6178 | Val   F1: 0.6093
# Epoch 31:
#   Train Loss: 0.5461 | Train Acc: 0.9137 | Train F1: 0.9137
#   Val   Loss: 1.1153 | Val   Acc: 0.6073 | Val   F1: 0.6029
# EarlyStopping counter: 1 out of 10
# Epoch 32:
#   Train Loss: 0.5307 | Train Acc: 0.9223 | Train F1: 0.9221
#   Val   Loss: 1.1576 | Val   Acc: 0.5969 | Val   F1: 0.5953
# EarlyStopping counter: 2 out of 10
# Epoch 33:
#   Train Loss: 0.5190 | Train Acc: 0.9386 | Train F1: 0.9383
#   Val   Loss: 1.1385 | Val   Acc: 0.6230 | Val   F1: 0.6163
# Epoch 34:
#   Train Loss: 0.5012 | Train Acc: 0.9348 | Train F1: 0.9347
#   Val   Loss: 1.1468 | Val   Acc: 0.5969 | Val   F1: 0.6005
# EarlyStopping counter: 1 out of 10
# Epoch 35:
#   Train Loss: 0.4875 | Train Acc: 0.9473 | Train F1: 0.9473
#   Val   Loss: 1.1694 | Val   Acc: 0.6073 | Val   F1: 0.6049
# EarlyStopping counter: 2 out of 10
# Epoch 36:
#   Train Loss: 0.4749 | Train Acc: 0.9569 | Train F1: 0.9568
#   Val   Loss: 1.1642 | Val   Acc: 0.6126 | Val   F1: 0.6060
# EarlyStopping counter: 3 out of 10
# Epoch 37:
#   Train Loss: 0.4691 | Train Acc: 0.9540 | Train F1: 0.9539
#   Val   Loss: 1.1504 | Val   Acc: 0.6283 | Val   F1: 0.6185
# Epoch 38:
#   Train Loss: 0.4489 | Train Acc: 0.9655 | Train F1: 0.9654
#   Val   Loss: 1.1856 | Val   Acc: 0.6335 | Val   F1: 0.6251
# Epoch 39:
#   Train Loss: 0.4376 | Train Acc: 0.9722 | Train F1: 0.9722
#   Val   Loss: 1.2428 | Val   Acc: 0.5864 | Val   F1: 0.5852
# EarlyStopping counter: 1 out of 10
# Epoch 40:
#   Train Loss: 0.4302 | Train Acc: 0.9760 | Train F1: 0.9760
#   Val   Loss: 1.2144 | Val   Acc: 0.6073 | Val   F1: 0.6053
# EarlyStopping counter: 2 out of 10
# Epoch 41:
#   Train Loss: 0.4304 | Train Acc: 0.9799 | Train F1: 0.9797
#   Val   Loss: 1.2188 | Val   Acc: 0.6178 | Val   F1: 0.6036
# EarlyStopping counter: 3 out of 10
# Epoch 42:
#   Train Loss: 0.4298 | Train Acc: 0.9741 | Train F1: 0.9741
#   Val   Loss: 1.2414 | Val   Acc: 0.6126 | Val   F1: 0.6100
# EarlyStopping counter: 4 out of 10
# Epoch 43:
#   Train Loss: 0.4131 | Train Acc: 0.9847 | Train F1: 0.9847
#   Val   Loss: 1.2154 | Val   Acc: 0.6178 | Val   F1: 0.6104
# EarlyStopping counter: 5 out of 10
# Epoch 44:
#   Train Loss: 0.4050 | Train Acc: 0.9866 | Train F1: 0.9866
#   Val   Loss: 1.2402 | Val   Acc: 0.6021 | Val   F1: 0.5971
# EarlyStopping counter: 6 out of 10
# Epoch 45:
#   Train Loss: 0.4073 | Train Acc: 0.9866 | Train F1: 0.9865
#   Val   Loss: 1.2988 | Val   Acc: 0.5864 | Val   F1: 0.5864
# EarlyStopping counter: 7 out of 10
# Epoch 46:
#   Train Loss: 0.3949 | Train Acc: 0.9914 | Train F1: 0.9914
#   Val   Loss: 1.2357 | Val   Acc: 0.6126 | Val   F1: 0.6104
# EarlyStopping counter: 8 out of 10
# Epoch 47:
#   Train Loss: 0.3939 | Train Acc: 0.9923 | Train F1: 0.9923
#   Val   Loss: 1.3024 | Val   Acc: 0.5864 | Val   F1: 0.5860
# EarlyStopping counter: 9 out of 10
# Epoch 48:
#   Train Loss: 0.3841 | Train Acc: 0.9962 | Train F1: 0.9961
#   Val   Loss: 1.2615 | Val   Acc: 0.5969 | Val   F1: 0.5976
# EarlyStopping counter: 10 out of 10
# Early stopping triggered!
# Finished training with lr=5e-05, weight_decay=0.01, Best Val F1=0.6251
#
# >>> Trying lr=5e-05, weight_decay=0.05
# Epoch 1:
#   Train Loss: 1.3858 | Train Acc: 0.2723 | Train F1: 0.1990
#   Val   Loss: 1.1867 | Val   Acc: 0.2513 | Val   F1: 0.2093
# Epoch 2:
#   Train Loss: 1.3759 | Train Acc: 0.3691 | Train F1: 0.2919
#   Val   Loss: 1.1829 | Val   Acc: 0.2827 | Val   F1: 0.2345
# Epoch 3:
#   Train Loss: 1.3510 | Train Acc: 0.3873 | Train F1: 0.3467
#   Val   Loss: 1.1559 | Val   Acc: 0.3822 | Val   F1: 0.3296
# Epoch 4:
#   Train Loss: 1.2809 | Train Acc: 0.4746 | Train F1: 0.4307
#   Val   Loss: 1.1165 | Val   Acc: 0.4293 | Val   F1: 0.3777
# Epoch 5:
#   Train Loss: 1.2161 | Train Acc: 0.5072 | Train F1: 0.4921
#   Val   Loss: 1.1130 | Val   Acc: 0.4031 | Val   F1: 0.3842
# Epoch 6:
#   Train Loss: 1.1507 | Train Acc: 0.5388 | Train F1: 0.5106
#   Val   Loss: 1.1404 | Val   Acc: 0.3770 | Val   F1: 0.3696
# EarlyStopping counter: 1 out of 10
# Epoch 7:
#   Train Loss: 1.1004 | Train Acc: 0.5820 | Train F1: 0.5708
#   Val   Loss: 1.0801 | Val   Acc: 0.4346 | Val   F1: 0.4251
# Epoch 8:
#   Train Loss: 1.0506 | Train Acc: 0.6079 | Train F1: 0.5933
#   Val   Loss: 1.0878 | Val   Acc: 0.4398 | Val   F1: 0.4383
# Epoch 9:
#   Train Loss: 1.0065 | Train Acc: 0.6443 | Train F1: 0.6383
#   Val   Loss: 1.0678 | Val   Acc: 0.4346 | Val   F1: 0.4265
# EarlyStopping counter: 1 out of 10
# Epoch 10:
#   Train Loss: 0.9736 | Train Acc: 0.6683 | Train F1: 0.6618
#   Val   Loss: 1.0839 | Val   Acc: 0.4921 | Val   F1: 0.4845
# Epoch 11:
#   Train Loss: 0.9417 | Train Acc: 0.6961 | Train F1: 0.6922
#   Val   Loss: 1.0840 | Val   Acc: 0.4764 | Val   F1: 0.4775
# EarlyStopping counter: 1 out of 10
# Epoch 12:
#   Train Loss: 0.9026 | Train Acc: 0.7095 | Train F1: 0.7006
#   Val   Loss: 1.0547 | Val   Acc: 0.5079 | Val   F1: 0.5028
# Epoch 13:
#   Train Loss: 0.8617 | Train Acc: 0.7430 | Train F1: 0.7393
#   Val   Loss: 1.0505 | Val   Acc: 0.5288 | Val   F1: 0.5274
# Epoch 14:
#   Train Loss: 0.8349 | Train Acc: 0.7469 | Train F1: 0.7412
#   Val   Loss: 1.0256 | Val   Acc: 0.5236 | Val   F1: 0.5140
# EarlyStopping counter: 1 out of 10
# Epoch 15:
#   Train Loss: 0.8065 | Train Acc: 0.7709 | Train F1: 0.7674
#   Val   Loss: 1.0189 | Val   Acc: 0.5445 | Val   F1: 0.5330
# Epoch 16:
#   Train Loss: 0.7798 | Train Acc: 0.7795 | Train F1: 0.7765
#   Val   Loss: 1.0531 | Val   Acc: 0.5131 | Val   F1: 0.5142
# EarlyStopping counter: 1 out of 10
# Epoch 17:
#   Train Loss: 0.7642 | Train Acc: 0.8073 | Train F1: 0.8048
#   Val   Loss: 1.0269 | Val   Acc: 0.5969 | Val   F1: 0.5792
# Epoch 18:
#   Train Loss: 0.7412 | Train Acc: 0.8140 | Train F1: 0.8113
#   Val   Loss: 1.0402 | Val   Acc: 0.5602 | Val   F1: 0.5445
# EarlyStopping counter: 1 out of 10
# Epoch 19:
#   Train Loss: 0.7249 | Train Acc: 0.8255 | Train F1: 0.8236
#   Val   Loss: 1.0234 | Val   Acc: 0.5969 | Val   F1: 0.5762
# EarlyStopping counter: 2 out of 10
# Epoch 20:
#   Train Loss: 0.7153 | Train Acc: 0.8284 | Train F1: 0.8263
#   Val   Loss: 1.0353 | Val   Acc: 0.5445 | Val   F1: 0.5433
# EarlyStopping counter: 3 out of 10
# Epoch 21:
#   Train Loss: 0.6887 | Train Acc: 0.8466 | Train F1: 0.8455
#   Val   Loss: 1.0631 | Val   Acc: 0.5550 | Val   F1: 0.5578
# EarlyStopping counter: 4 out of 10
# Epoch 22:
#   Train Loss: 0.6744 | Train Acc: 0.8466 | Train F1: 0.8445
#   Val   Loss: 1.0786 | Val   Acc: 0.5654 | Val   F1: 0.5634
# EarlyStopping counter: 5 out of 10
# Epoch 23:
#   Train Loss: 0.6513 | Train Acc: 0.8667 | Train F1: 0.8652
#   Val   Loss: 1.0702 | Val   Acc: 0.5707 | Val   F1: 0.5648
# EarlyStopping counter: 6 out of 10
# Epoch 24:
#   Train Loss: 0.6294 | Train Acc: 0.8792 | Train F1: 0.8782
#   Val   Loss: 1.0537 | Val   Acc: 0.6230 | Val   F1: 0.6106
# Epoch 25:
#   Train Loss: 0.6132 | Train Acc: 0.9003 | Train F1: 0.8994
#   Val   Loss: 1.0681 | Val   Acc: 0.5864 | Val   F1: 0.5812
# EarlyStopping counter: 1 out of 10
# Epoch 26:
#   Train Loss: 0.6009 | Train Acc: 0.8993 | Train F1: 0.8983
#   Val   Loss: 1.0454 | Val   Acc: 0.5812 | Val   F1: 0.5813
# EarlyStopping counter: 2 out of 10
# Epoch 27:
#   Train Loss: 0.5884 | Train Acc: 0.9051 | Train F1: 0.9045
#   Val   Loss: 1.0674 | Val   Acc: 0.5759 | Val   F1: 0.5731
# EarlyStopping counter: 3 out of 10
# Epoch 28:
#   Train Loss: 0.5622 | Train Acc: 0.9223 | Train F1: 0.9220
#   Val   Loss: 1.0609 | Val   Acc: 0.6126 | Val   F1: 0.6067
# EarlyStopping counter: 4 out of 10
# Epoch 29:
#   Train Loss: 0.5541 | Train Acc: 0.9204 | Train F1: 0.9198
#   Val   Loss: 1.0993 | Val   Acc: 0.5969 | Val   F1: 0.5933
# EarlyStopping counter: 5 out of 10
# Epoch 30:
#   Train Loss: 0.5416 | Train Acc: 0.9300 | Train F1: 0.9294
#   Val   Loss: 1.1131 | Val   Acc: 0.5602 | Val   F1: 0.5607
# EarlyStopping counter: 6 out of 10
# Epoch 31:
#   Train Loss: 0.5353 | Train Acc: 0.9329 | Train F1: 0.9323
#   Val   Loss: 1.1184 | Val   Acc: 0.5812 | Val   F1: 0.5807
# EarlyStopping counter: 7 out of 10
# Epoch 32:
#   Train Loss: 0.5291 | Train Acc: 0.9377 | Train F1: 0.9370
#   Val   Loss: 1.0912 | Val   Acc: 0.5916 | Val   F1: 0.5897
# EarlyStopping counter: 8 out of 10
# Epoch 33:
#   Train Loss: 0.5028 | Train Acc: 0.9530 | Train F1: 0.9525
#   Val   Loss: 1.0866 | Val   Acc: 0.6335 | Val   F1: 0.6227
# Epoch 34:
#   Train Loss: 0.4886 | Train Acc: 0.9501 | Train F1: 0.9498
#   Val   Loss: 1.1077 | Val   Acc: 0.6073 | Val   F1: 0.6078
# EarlyStopping counter: 1 out of 10
# Epoch 35:
#   Train Loss: 0.4774 | Train Acc: 0.9578 | Train F1: 0.9572
#   Val   Loss: 1.1186 | Val   Acc: 0.6440 | Val   F1: 0.6280
# Epoch 36:
#   Train Loss: 0.4710 | Train Acc: 0.9645 | Train F1: 0.9641
#   Val   Loss: 1.0928 | Val   Acc: 0.6440 | Val   F1: 0.6364
# Epoch 37:
#   Train Loss: 0.4650 | Train Acc: 0.9607 | Train F1: 0.9604
#   Val   Loss: 1.0981 | Val   Acc: 0.6649 | Val   F1: 0.6575
# Epoch 38:
#   Train Loss: 0.4503 | Train Acc: 0.9674 | Train F1: 0.9670
#   Val   Loss: 1.1073 | Val   Acc: 0.6492 | Val   F1: 0.6460
# EarlyStopping counter: 1 out of 10
# Epoch 39:
#   Train Loss: 0.4459 | Train Acc: 0.9732 | Train F1: 0.9728
#   Val   Loss: 1.1740 | Val   Acc: 0.5864 | Val   F1: 0.5894
# EarlyStopping counter: 2 out of 10
# Epoch 40:
#   Train Loss: 0.4362 | Train Acc: 0.9760 | Train F1: 0.9758
#   Val   Loss: 1.1224 | Val   Acc: 0.6230 | Val   F1: 0.6216
# EarlyStopping counter: 3 out of 10
# Epoch 41:
#   Train Loss: 0.4274 | Train Acc: 0.9808 | Train F1: 0.9806
#   Val   Loss: 1.1296 | Val   Acc: 0.6283 | Val   F1: 0.6249
# EarlyStopping counter: 4 out of 10
# Epoch 42:
#   Train Loss: 0.4154 | Train Acc: 0.9837 | Train F1: 0.9835
#   Val   Loss: 1.1366 | Val   Acc: 0.6440 | Val   F1: 0.6357
# EarlyStopping counter: 5 out of 10
# Epoch 43:
#   Train Loss: 0.4064 | Train Acc: 0.9866 | Train F1: 0.9865
#   Val   Loss: 1.1253 | Val   Acc: 0.6492 | Val   F1: 0.6399
# EarlyStopping counter: 6 out of 10
# Epoch 44:
#   Train Loss: 0.4064 | Train Acc: 0.9866 | Train F1: 0.9865
#   Val   Loss: 1.1655 | Val   Acc: 0.6021 | Val   F1: 0.6032
# EarlyStopping counter: 7 out of 10
# Epoch 45:
#   Train Loss: 0.3979 | Train Acc: 0.9875 | Train F1: 0.9875
#   Val   Loss: 1.1479 | Val   Acc: 0.6283 | Val   F1: 0.6265
# EarlyStopping counter: 8 out of 10
# Epoch 46:
#   Train Loss: 0.4050 | Train Acc: 0.9827 | Train F1: 0.9826
#   Val   Loss: 1.1397 | Val   Acc: 0.6597 | Val   F1: 0.6507
# EarlyStopping counter: 9 out of 10
# Epoch 47:
#   Train Loss: 0.3905 | Train Acc: 0.9923 | Train F1: 0.9923
#   Val   Loss: 1.1735 | Val   Acc: 0.6126 | Val   F1: 0.6125
# EarlyStopping counter: 10 out of 10
# Early stopping triggered!
# Finished training with lr=5e-05, weight_decay=0.05, Best Val F1=0.6575
#
# >>> Trying lr=3e-05, weight_decay=0.01
# Epoch 1:
#   Train Loss: 1.3869 | Train Acc: 0.2589 | Train F1: 0.1717
#   Val   Loss: 1.1921 | Val   Acc: 0.1832 | Val   F1: 0.1168
# Epoch 2:
#   Train Loss: 1.3792 | Train Acc: 0.2752 | Train F1: 0.1429
#   Val   Loss: 1.1919 | Val   Acc: 0.1885 | Val   F1: 0.0953
# EarlyStopping counter: 1 out of 10
# Epoch 3:
#   Train Loss: 1.3706 | Train Acc: 0.2905 | Train F1: 0.1685
#   Val   Loss: 1.1917 | Val   Acc: 0.2147 | Val   F1: 0.1422
# Epoch 4:
#   Train Loss: 1.3534 | Train Acc: 0.3500 | Train F1: 0.2663
#   Val   Loss: 1.1857 | Val   Acc: 0.2199 | Val   F1: 0.1936
# Epoch 5:
#   Train Loss: 1.3216 | Train Acc: 0.4314 | Train F1: 0.4010
#   Val   Loss: 1.1787 | Val   Acc: 0.2618 | Val   F1: 0.2396
# Epoch 6:
#   Train Loss: 1.2729 | Train Acc: 0.4803 | Train F1: 0.4413
#   Val   Loss: 1.1562 | Val   Acc: 0.3508 | Val   F1: 0.3194
# Epoch 7:
#   Train Loss: 1.2220 | Train Acc: 0.4947 | Train F1: 0.4628
#   Val   Loss: 1.1331 | Val   Acc: 0.3874 | Val   F1: 0.3745
# Epoch 8:
#   Train Loss: 1.1833 | Train Acc: 0.5120 | Train F1: 0.4877
#   Val   Loss: 1.1433 | Val   Acc: 0.4031 | Val   F1: 0.3924
# Epoch 9:
#   Train Loss: 1.1460 | Train Acc: 0.5465 | Train F1: 0.5349
#   Val   Loss: 1.1355 | Val   Acc: 0.3979 | Val   F1: 0.3922
# EarlyStopping counter: 1 out of 10
# Epoch 10:
#   Train Loss: 1.1224 | Train Acc: 0.5618 | Train F1: 0.5484
#   Val   Loss: 1.1299 | Val   Acc: 0.4084 | Val   F1: 0.4035
# Epoch 11:
#   Train Loss: 1.0934 | Train Acc: 0.5781 | Train F1: 0.5735
#   Val   Loss: 1.1218 | Val   Acc: 0.4031 | Val   F1: 0.4027
# EarlyStopping counter: 1 out of 10
# Epoch 12:
#   Train Loss: 1.0751 | Train Acc: 0.6021 | Train F1: 0.5902
#   Val   Loss: 1.1319 | Val   Acc: 0.4084 | Val   F1: 0.4061
# Epoch 13:
#   Train Loss: 1.0441 | Train Acc: 0.6127 | Train F1: 0.6036
#   Val   Loss: 1.1308 | Val   Acc: 0.4136 | Val   F1: 0.4145
# Epoch 14:
#   Train Loss: 1.0230 | Train Acc: 0.6357 | Train F1: 0.6296
#   Val   Loss: 1.0910 | Val   Acc: 0.4764 | Val   F1: 0.4692
# Epoch 15:
#   Train Loss: 1.0020 | Train Acc: 0.6261 | Train F1: 0.6147
#   Val   Loss: 1.1233 | Val   Acc: 0.4660 | Val   F1: 0.4670
# EarlyStopping counter: 1 out of 10
# Epoch 16:
#   Train Loss: 0.9793 | Train Acc: 0.6520 | Train F1: 0.6482
#   Val   Loss: 1.1132 | Val   Acc: 0.4503 | Val   F1: 0.4520
# EarlyStopping counter: 2 out of 10
# Epoch 17:
#   Train Loss: 0.9619 | Train Acc: 0.6644 | Train F1: 0.6579
#   Val   Loss: 1.1048 | Val   Acc: 0.4607 | Val   F1: 0.4625
# EarlyStopping counter: 3 out of 10
# Epoch 18:
#   Train Loss: 0.9395 | Train Acc: 0.6942 | Train F1: 0.6895
#   Val   Loss: 1.1007 | Val   Acc: 0.4869 | Val   F1: 0.4854
# Epoch 19:
#   Train Loss: 0.9239 | Train Acc: 0.6922 | Train F1: 0.6854
#   Val   Loss: 1.1084 | Val   Acc: 0.4921 | Val   F1: 0.4928
# Epoch 20:
#   Train Loss: 0.9049 | Train Acc: 0.7114 | Train F1: 0.7038
#   Val   Loss: 1.0690 | Val   Acc: 0.5393 | Val   F1: 0.5348
# Epoch 21:
#   Train Loss: 0.8849 | Train Acc: 0.7267 | Train F1: 0.7224
#   Val   Loss: 1.0620 | Val   Acc: 0.5131 | Val   F1: 0.5079
# EarlyStopping counter: 1 out of 10
# Epoch 22:
#   Train Loss: 0.8691 | Train Acc: 0.7277 | Train F1: 0.7182
#   Val   Loss: 1.0514 | Val   Acc: 0.5183 | Val   F1: 0.5103
# EarlyStopping counter: 2 out of 10
# Epoch 23:
#   Train Loss: 0.8616 | Train Acc: 0.7421 | Train F1: 0.7384
#   Val   Loss: 1.0847 | Val   Acc: 0.5183 | Val   F1: 0.5161
# EarlyStopping counter: 3 out of 10
# Epoch 24:
#   Train Loss: 0.8437 | Train Acc: 0.7507 | Train F1: 0.7463
#   Val   Loss: 1.0593 | Val   Acc: 0.5026 | Val   F1: 0.5007
# EarlyStopping counter: 4 out of 10
# Epoch 25:
#   Train Loss: 0.8266 | Train Acc: 0.7593 | Train F1: 0.7528
#   Val   Loss: 1.0534 | Val   Acc: 0.5393 | Val   F1: 0.5351
# Epoch 26:
#   Train Loss: 0.8064 | Train Acc: 0.7843 | Train F1: 0.7813
#   Val   Loss: 1.0647 | Val   Acc: 0.5183 | Val   F1: 0.5190
# EarlyStopping counter: 1 out of 10
# Epoch 27:
#   Train Loss: 0.7907 | Train Acc: 0.7958 | Train F1: 0.7925
#   Val   Loss: 1.0523 | Val   Acc: 0.5654 | Val   F1: 0.5627
# Epoch 28:
#   Train Loss: 0.7800 | Train Acc: 0.7843 | Train F1: 0.7815
#   Val   Loss: 1.0448 | Val   Acc: 0.5864 | Val   F1: 0.5761
# Epoch 29:
#   Train Loss: 0.7650 | Train Acc: 0.7929 | Train F1: 0.7910
#   Val   Loss: 1.0625 | Val   Acc: 0.5393 | Val   F1: 0.5391
# EarlyStopping counter: 1 out of 10
# Epoch 30:
#   Train Loss: 0.7576 | Train Acc: 0.7977 | Train F1: 0.7942
#   Val   Loss: 1.0721 | Val   Acc: 0.5393 | Val   F1: 0.5391
# EarlyStopping counter: 2 out of 10
# Epoch 31:
#   Train Loss: 0.7437 | Train Acc: 0.8140 | Train F1: 0.8120
#   Val   Loss: 1.0507 | Val   Acc: 0.5759 | Val   F1: 0.5744
# EarlyStopping counter: 3 out of 10
# Epoch 32:
#   Train Loss: 0.7302 | Train Acc: 0.8159 | Train F1: 0.8140
#   Val   Loss: 1.0275 | Val   Acc: 0.5759 | Val   F1: 0.5552
# EarlyStopping counter: 4 out of 10
# Epoch 33:
#   Train Loss: 0.7168 | Train Acc: 0.8255 | Train F1: 0.8236
#   Val   Loss: 1.0375 | Val   Acc: 0.5654 | Val   F1: 0.5615
# EarlyStopping counter: 5 out of 10
# Epoch 34:
#   Train Loss: 0.7010 | Train Acc: 0.8447 | Train F1: 0.8429
#   Val   Loss: 1.0782 | Val   Acc: 0.5759 | Val   F1: 0.5722
# EarlyStopping counter: 6 out of 10
# Epoch 35:
#   Train Loss: 0.6911 | Train Acc: 0.8437 | Train F1: 0.8423
#   Val   Loss: 1.0456 | Val   Acc: 0.5654 | Val   F1: 0.5612
# EarlyStopping counter: 7 out of 10
# Epoch 36:
#   Train Loss: 0.6766 | Train Acc: 0.8581 | Train F1: 0.8563
#   Val   Loss: 1.0380 | Val   Acc: 0.6021 | Val   F1: 0.5877
# Epoch 37:
#   Train Loss: 0.6686 | Train Acc: 0.8600 | Train F1: 0.8585
#   Val   Loss: 1.0524 | Val   Acc: 0.5864 | Val   F1: 0.5809
# EarlyStopping counter: 1 out of 10
# Epoch 38:
#   Train Loss: 0.6545 | Train Acc: 0.8744 | Train F1: 0.8735
#   Val   Loss: 1.0451 | Val   Acc: 0.5654 | Val   F1: 0.5589
# EarlyStopping counter: 2 out of 10
# Epoch 39:
#   Train Loss: 0.6555 | Train Acc: 0.8658 | Train F1: 0.8641
#   Val   Loss: 1.0418 | Val   Acc: 0.5812 | Val   F1: 0.5679
# EarlyStopping counter: 3 out of 10
# Epoch 40:
#   Train Loss: 0.6340 | Train Acc: 0.8802 | Train F1: 0.8794
#   Val   Loss: 1.0886 | Val   Acc: 0.5969 | Val   F1: 0.5888
# Epoch 41:
#   Train Loss: 0.6259 | Train Acc: 0.8859 | Train F1: 0.8853
#   Val   Loss: 1.0448 | Val   Acc: 0.5916 | Val   F1: 0.5839
# EarlyStopping counter: 1 out of 10
# Epoch 42:
#   Train Loss: 0.6125 | Train Acc: 0.8917 | Train F1: 0.8912
#   Val   Loss: 1.0455 | Val   Acc: 0.6126 | Val   F1: 0.5989
# Epoch 43:
#   Train Loss: 0.6066 | Train Acc: 0.8965 | Train F1: 0.8963
#   Val   Loss: 1.0513 | Val   Acc: 0.6073 | Val   F1: 0.5984
# EarlyStopping counter: 1 out of 10
# Epoch 44:
#   Train Loss: 0.5897 | Train Acc: 0.9070 | Train F1: 0.9065
#   Val   Loss: 1.1146 | Val   Acc: 0.5288 | Val   F1: 0.5308
# EarlyStopping counter: 2 out of 10
# Epoch 45:
#   Train Loss: 0.5800 | Train Acc: 0.9156 | Train F1: 0.9152
#   Val   Loss: 1.1081 | Val   Acc: 0.5445 | Val   F1: 0.5459
# EarlyStopping counter: 3 out of 10
# Epoch 46:
#   Train Loss: 0.5713 | Train Acc: 0.9137 | Train F1: 0.9133
#   Val   Loss: 1.0822 | Val   Acc: 0.5916 | Val   F1: 0.5865
# EarlyStopping counter: 4 out of 10
# Epoch 47:
#   Train Loss: 0.5617 | Train Acc: 0.9233 | Train F1: 0.9228
#   Val   Loss: 1.0993 | Val   Acc: 0.5812 | Val   F1: 0.5774
# EarlyStopping counter: 5 out of 10
# Epoch 48:
#   Train Loss: 0.5486 | Train Acc: 0.9243 | Train F1: 0.9239
#   Val   Loss: 1.0948 | Val   Acc: 0.5969 | Val   F1: 0.5924
# EarlyStopping counter: 6 out of 10
# Epoch 49:
#   Train Loss: 0.5434 | Train Acc: 0.9319 | Train F1: 0.9316
#   Val   Loss: 1.1075 | Val   Acc: 0.5916 | Val   F1: 0.5856
# EarlyStopping counter: 7 out of 10
# Epoch 50:
#   Train Loss: 0.5345 | Train Acc: 0.9281 | Train F1: 0.9275
#   Val   Loss: 1.1431 | Val   Acc: 0.5864 | Val   F1: 0.5824
# EarlyStopping counter: 8 out of 10
# Epoch 51:
#   Train Loss: 0.5176 | Train Acc: 0.9425 | Train F1: 0.9420
#   Val   Loss: 1.1109 | Val   Acc: 0.5916 | Val   F1: 0.5884
# EarlyStopping counter: 9 out of 10
# Epoch 52:
#   Train Loss: 0.5077 | Train Acc: 0.9549 | Train F1: 0.9548
#   Val   Loss: 1.1260 | Val   Acc: 0.5916 | Val   F1: 0.5837
# EarlyStopping counter: 10 out of 10
# Early stopping triggered!
# Finished training with lr=3e-05, weight_decay=0.01, Best Val F1=0.5989
#
# >>> Trying lr=3e-05, weight_decay=0.05
# Epoch 1:
#   Train Loss: 1.3868 | Train Acc: 0.2522 | Train F1: 0.1247
#   Val   Loss: 1.1902 | Val   Acc: 0.1990 | Val   F1: 0.1049
# Epoch 2:
#   Train Loss: 1.3820 | Train Acc: 0.2733 | Train F1: 0.1611
#   Val   Loss: 1.1866 | Val   Acc: 0.2513 | Val   F1: 0.1850
# Epoch 3:
#   Train Loss: 1.3754 | Train Acc: 0.3212 | Train F1: 0.2405
#   Val   Loss: 1.1823 | Val   Acc: 0.2775 | Val   F1: 0.2351
# Epoch 4:
#   Train Loss: 1.3588 | Train Acc: 0.3758 | Train F1: 0.2950
#   Val   Loss: 1.1660 | Val   Acc: 0.3351 | Val   F1: 0.2997
# Epoch 5:
#   Train Loss: 1.3128 | Train Acc: 0.4343 | Train F1: 0.3714
#   Val   Loss: 1.1414 | Val   Acc: 0.3194 | Val   F1: 0.2756
# EarlyStopping counter: 1 out of 10
# Epoch 6:
#   Train Loss: 1.2600 | Train Acc: 0.4631 | Train F1: 0.4079
#   Val   Loss: 1.1174 | Val   Acc: 0.4136 | Val   F1: 0.3952
# Epoch 7:
#   Train Loss: 1.2195 | Train Acc: 0.5101 | Train F1: 0.4681
#   Val   Loss: 1.1139 | Val   Acc: 0.3927 | Val   F1: 0.3645
# EarlyStopping counter: 1 out of 10
# Epoch 8:
#   Train Loss: 1.1795 | Train Acc: 0.5139 | Train F1: 0.4731
#   Val   Loss: 1.1040 | Val   Acc: 0.3717 | Val   F1: 0.3525
# EarlyStopping counter: 2 out of 10
# Epoch 9:
#   Train Loss: 1.1435 | Train Acc: 0.5532 | Train F1: 0.5210
#   Val   Loss: 1.0976 | Val   Acc: 0.4031 | Val   F1: 0.3789
# EarlyStopping counter: 3 out of 10
# Epoch 10:
#   Train Loss: 1.1067 | Train Acc: 0.5705 | Train F1: 0.5316
#   Val   Loss: 1.0995 | Val   Acc: 0.4084 | Val   F1: 0.3976
# Epoch 11:
#   Train Loss: 1.0767 | Train Acc: 0.5964 | Train F1: 0.5662
#   Val   Loss: 1.0802 | Val   Acc: 0.4398 | Val   F1: 0.4292
# Epoch 12:
#   Train Loss: 1.0464 | Train Acc: 0.6136 | Train F1: 0.5918
#   Val   Loss: 1.0911 | Val   Acc: 0.4241 | Val   F1: 0.4048
# EarlyStopping counter: 1 out of 10
# Epoch 13:
#   Train Loss: 1.0251 | Train Acc: 0.6318 | Train F1: 0.6115
#   Val   Loss: 1.1123 | Val   Acc: 0.4555 | Val   F1: 0.4393
# Epoch 14:
#   Train Loss: 1.0003 | Train Acc: 0.6491 | Train F1: 0.6307
#   Val   Loss: 1.0449 | Val   Acc: 0.4974 | Val   F1: 0.4784
# Epoch 15:
#   Train Loss: 0.9823 | Train Acc: 0.6635 | Train F1: 0.6486
#   Val   Loss: 1.0902 | Val   Acc: 0.5026 | Val   F1: 0.4802
# Epoch 16:
#   Train Loss: 0.9576 | Train Acc: 0.6673 | Train F1: 0.6527
#   Val   Loss: 1.0678 | Val   Acc: 0.4660 | Val   F1: 0.4456
# EarlyStopping counter: 1 out of 10
# Epoch 17:
#   Train Loss: 0.9408 | Train Acc: 0.6980 | Train F1: 0.6871
#   Val   Loss: 1.0737 | Val   Acc: 0.5340 | Val   F1: 0.5203
# Epoch 18:
#   Train Loss: 0.9171 | Train Acc: 0.7095 | Train F1: 0.7006
#   Val   Loss: 1.0424 | Val   Acc: 0.5183 | Val   F1: 0.5064
# EarlyStopping counter: 1 out of 10
# Epoch 19:
#   Train Loss: 0.9003 | Train Acc: 0.7229 | Train F1: 0.7163
#   Val   Loss: 1.0611 | Val   Acc: 0.5026 | Val   F1: 0.4960
# EarlyStopping counter: 2 out of 10
# Epoch 20:
#   Train Loss: 0.8807 | Train Acc: 0.7402 | Train F1: 0.7345
#   Val   Loss: 1.0277 | Val   Acc: 0.5340 | Val   F1: 0.5199
# EarlyStopping counter: 3 out of 10
# Epoch 21:
#   Train Loss: 0.8656 | Train Acc: 0.7498 | Train F1: 0.7456
#   Val   Loss: 1.0546 | Val   Acc: 0.5236 | Val   F1: 0.5129
# EarlyStopping counter: 4 out of 10
# Epoch 22:
#   Train Loss: 0.8461 | Train Acc: 0.7469 | Train F1: 0.7409
#   Val   Loss: 1.0299 | Val   Acc: 0.5288 | Val   F1: 0.5195
# EarlyStopping counter: 5 out of 10
# Epoch 23:
#   Train Loss: 0.8346 | Train Acc: 0.7661 | Train F1: 0.7605
#   Val   Loss: 1.0198 | Val   Acc: 0.5340 | Val   F1: 0.5250
# Epoch 24:
#   Train Loss: 0.8172 | Train Acc: 0.7756 | Train F1: 0.7709
#   Val   Loss: 1.0326 | Val   Acc: 0.5497 | Val   F1: 0.5382
# Epoch 25:
#   Train Loss: 0.7981 | Train Acc: 0.7872 | Train F1: 0.7846
#   Val   Loss: 1.0297 | Val   Acc: 0.5550 | Val   F1: 0.5504
# Epoch 26:
#   Train Loss: 0.7829 | Train Acc: 0.7996 | Train F1: 0.7973
#   Val   Loss: 1.0431 | Val   Acc: 0.5497 | Val   F1: 0.5382
# EarlyStopping counter: 1 out of 10
# Epoch 27:
#   Train Loss: 0.7672 | Train Acc: 0.8102 | Train F1: 0.8073
#   Val   Loss: 1.0128 | Val   Acc: 0.5654 | Val   F1: 0.5611
# Epoch 28:
#   Train Loss: 0.7521 | Train Acc: 0.8178 | Train F1: 0.8155
#   Val   Loss: 1.0563 | Val   Acc: 0.5497 | Val   F1: 0.5422
# EarlyStopping counter: 1 out of 10
# Epoch 29:
#   Train Loss: 0.7400 | Train Acc: 0.8217 | Train F1: 0.8198
#   Val   Loss: 1.0132 | Val   Acc: 0.5707 | Val   F1: 0.5598
# EarlyStopping counter: 2 out of 10
# Epoch 30:
#   Train Loss: 0.7209 | Train Acc: 0.8370 | Train F1: 0.8354
#   Val   Loss: 1.0288 | Val   Acc: 0.5707 | Val   F1: 0.5649
# Epoch 31:
#   Train Loss: 0.7115 | Train Acc: 0.8332 | Train F1: 0.8322
#   Val   Loss: 1.0359 | Val   Acc: 0.5602 | Val   F1: 0.5508
# EarlyStopping counter: 1 out of 10
# Epoch 32:
#   Train Loss: 0.7008 | Train Acc: 0.8351 | Train F1: 0.8330
#   Val   Loss: 1.0106 | Val   Acc: 0.5654 | Val   F1: 0.5565
# EarlyStopping counter: 2 out of 10
# Epoch 33:
#   Train Loss: 0.6892 | Train Acc: 0.8428 | Train F1: 0.8418
#   Val   Loss: 1.0654 | Val   Acc: 0.5550 | Val   F1: 0.5508
# EarlyStopping counter: 3 out of 10
# Epoch 34:
#   Train Loss: 0.6797 | Train Acc: 0.8476 | Train F1: 0.8462
#   Val   Loss: 1.0504 | Val   Acc: 0.5812 | Val   F1: 0.5745
# Epoch 35:
#   Train Loss: 0.6640 | Train Acc: 0.8485 | Train F1: 0.8469
#   Val   Loss: 1.0815 | Val   Acc: 0.5602 | Val   F1: 0.5511
# EarlyStopping counter: 1 out of 10
# Epoch 36:
#   Train Loss: 0.6512 | Train Acc: 0.8629 | Train F1: 0.8622
#   Val   Loss: 1.0528 | Val   Acc: 0.5707 | Val   F1: 0.5646
# EarlyStopping counter: 2 out of 10
# Epoch 37:
#   Train Loss: 0.6462 | Train Acc: 0.8619 | Train F1: 0.8605
#   Val   Loss: 1.0525 | Val   Acc: 0.5969 | Val   F1: 0.5861
# Epoch 38:
#   Train Loss: 0.6270 | Train Acc: 0.8773 | Train F1: 0.8762
#   Val   Loss: 1.0508 | Val   Acc: 0.6073 | Val   F1: 0.5966
# Epoch 39:
#   Train Loss: 0.6161 | Train Acc: 0.8869 | Train F1: 0.8861
#   Val   Loss: 1.0491 | Val   Acc: 0.6178 | Val   F1: 0.6104
# Epoch 40:
#   Train Loss: 0.6034 | Train Acc: 0.8849 | Train F1: 0.8835
#   Val   Loss: 1.0666 | Val   Acc: 0.5864 | Val   F1: 0.5839
# EarlyStopping counter: 1 out of 10
# Epoch 41:
#   Train Loss: 0.5952 | Train Acc: 0.8984 | Train F1: 0.8974
#   Val   Loss: 1.0685 | Val   Acc: 0.5864 | Val   F1: 0.5841
# EarlyStopping counter: 2 out of 10
# Epoch 42:
#   Train Loss: 0.5810 | Train Acc: 0.9022 | Train F1: 0.9014
#   Val   Loss: 1.0673 | Val   Acc: 0.5969 | Val   F1: 0.5896
# EarlyStopping counter: 3 out of 10
# Epoch 43:
#   Train Loss: 0.5693 | Train Acc: 0.9137 | Train F1: 0.9129
#   Val   Loss: 1.0801 | Val   Acc: 0.6073 | Val   F1: 0.6008
# EarlyStopping counter: 4 out of 10
# Epoch 44:
#   Train Loss: 0.5550 | Train Acc: 0.9156 | Train F1: 0.9152
#   Val   Loss: 1.1007 | Val   Acc: 0.5864 | Val   F1: 0.5806
# EarlyStopping counter: 5 out of 10
# Epoch 45:
#   Train Loss: 0.5423 | Train Acc: 0.9281 | Train F1: 0.9276
#   Val   Loss: 1.1070 | Val   Acc: 0.6021 | Val   F1: 0.5977
# EarlyStopping counter: 6 out of 10
# Epoch 46:
#   Train Loss: 0.5449 | Train Acc: 0.9166 | Train F1: 0.9161
#   Val   Loss: 1.1052 | Val   Acc: 0.5916 | Val   F1: 0.5887
# EarlyStopping counter: 7 out of 10
# Epoch 47:
#   Train Loss: 0.5336 | Train Acc: 0.9262 | Train F1: 0.9258
#   Val   Loss: 1.1063 | Val   Acc: 0.6021 | Val   F1: 0.5958
# EarlyStopping counter: 8 out of 10
# Epoch 48:
#   Train Loss: 0.5233 | Train Acc: 0.9358 | Train F1: 0.9353
#   Val   Loss: 1.1114 | Val   Acc: 0.5916 | Val   F1: 0.5905
# EarlyStopping counter: 9 out of 10
# Epoch 49:
#   Train Loss: 0.5083 | Train Acc: 0.9434 | Train F1: 0.9432
#   Val   Loss: 1.1207 | Val   Acc: 0.5916 | Val   F1: 0.5864
# EarlyStopping counter: 10 out of 10
# Early stopping triggered!
# Finished training with lr=3e-05, weight_decay=0.05, Best Val F1=0.6104
#
# >>> Trying lr=1e-05, weight_decay=0.01
# Epoch 1:
#   Train Loss: 1.3849 | Train Acc: 0.2608 | Train F1: 0.1380
#   Val   Loss: 1.1907 | Val   Acc: 0.2094 | Val   F1: 0.1067
# Epoch 2:
#   Train Loss: 1.3831 | Train Acc: 0.3020 | Train F1: 0.1909
#   Val   Loss: 1.1906 | Val   Acc: 0.2042 | Val   F1: 0.1290
# Epoch 3:
#   Train Loss: 1.3814 | Train Acc: 0.3058 | Train F1: 0.1932
#   Val   Loss: 1.1901 | Val   Acc: 0.2147 | Val   F1: 0.1275
# EarlyStopping counter: 1 out of 10
# Epoch 4:
#   Train Loss: 1.3790 | Train Acc: 0.3404 | Train F1: 0.2270
#   Val   Loss: 1.1893 | Val   Acc: 0.1832 | Val   F1: 0.1269
# EarlyStopping counter: 2 out of 10
# Epoch 5:
#   Train Loss: 1.3766 | Train Acc: 0.3528 | Train F1: 0.2578
#   Val   Loss: 1.1885 | Val   Acc: 0.1832 | Val   F1: 0.1279
# EarlyStopping counter: 3 out of 10
# Epoch 6:
#   Train Loss: 1.3731 | Train Acc: 0.3576 | Train F1: 0.2589
#   Val   Loss: 1.1875 | Val   Acc: 0.2042 | Val   F1: 0.1545
# Epoch 7:
#   Train Loss: 1.3684 | Train Acc: 0.3634 | Train F1: 0.2730
#   Val   Loss: 1.1859 | Val   Acc: 0.2199 | Val   F1: 0.1769
# Epoch 8:
#   Train Loss: 1.3618 | Train Acc: 0.3931 | Train F1: 0.3376
#   Val   Loss: 1.1828 | Val   Acc: 0.2513 | Val   F1: 0.2275
# Epoch 9:
#   Train Loss: 1.3534 | Train Acc: 0.3950 | Train F1: 0.3456
#   Val   Loss: 1.1808 | Val   Acc: 0.2408 | Val   F1: 0.2128
# EarlyStopping counter: 1 out of 10
# Epoch 10:
#   Train Loss: 1.3427 | Train Acc: 0.4161 | Train F1: 0.3669
#   Val   Loss: 1.1773 | Val   Acc: 0.2775 | Val   F1: 0.2610
# Epoch 11:
#   Train Loss: 1.3301 | Train Acc: 0.4151 | Train F1: 0.3701
#   Val   Loss: 1.1742 | Val   Acc: 0.2984 | Val   F1: 0.2735
# Epoch 12:
#   Train Loss: 1.3157 | Train Acc: 0.4209 | Train F1: 0.3742
#   Val   Loss: 1.1712 | Val   Acc: 0.2880 | Val   F1: 0.2633
# EarlyStopping counter: 1 out of 10
# Epoch 13:
#   Train Loss: 1.3016 | Train Acc: 0.4401 | Train F1: 0.3966
#   Val   Loss: 1.1680 | Val   Acc: 0.3037 | Val   F1: 0.2779
# Epoch 14:
#   Train Loss: 1.2882 | Train Acc: 0.4430 | Train F1: 0.3920
#   Val   Loss: 1.1650 | Val   Acc: 0.3141 | Val   F1: 0.2894
# Epoch 15:
#   Train Loss: 1.2753 | Train Acc: 0.4583 | Train F1: 0.4111
#   Val   Loss: 1.1608 | Val   Acc: 0.3298 | Val   F1: 0.3105
# Epoch 16:
#   Train Loss: 1.2622 | Train Acc: 0.4631 | Train F1: 0.4241
#   Val   Loss: 1.1575 | Val   Acc: 0.3403 | Val   F1: 0.3265
# Epoch 17:
#   Train Loss: 1.2497 | Train Acc: 0.4688 | Train F1: 0.4299
#   Val   Loss: 1.1602 | Val   Acc: 0.3298 | Val   F1: 0.3164
# EarlyStopping counter: 1 out of 10
# Epoch 18:
#   Train Loss: 1.2398 | Train Acc: 0.4775 | Train F1: 0.4374
#   Val   Loss: 1.1549 | Val   Acc: 0.3613 | Val   F1: 0.3581
# Epoch 19:
#   Train Loss: 1.2300 | Train Acc: 0.4871 | Train F1: 0.4546
#   Val   Loss: 1.1503 | Val   Acc: 0.3508 | Val   F1: 0.3450
# EarlyStopping counter: 1 out of 10
# Epoch 20:
#   Train Loss: 1.2192 | Train Acc: 0.5024 | Train F1: 0.4794
#   Val   Loss: 1.1503 | Val   Acc: 0.3508 | Val   F1: 0.3482
# EarlyStopping counter: 2 out of 10
# Epoch 21:
#   Train Loss: 1.2081 | Train Acc: 0.5034 | Train F1: 0.4790
#   Val   Loss: 1.1468 | Val   Acc: 0.3665 | Val   F1: 0.3614
# Epoch 22:
#   Train Loss: 1.1970 | Train Acc: 0.5197 | Train F1: 0.4983
#   Val   Loss: 1.1434 | Val   Acc: 0.3455 | Val   F1: 0.3379
# EarlyStopping counter: 1 out of 10
# Epoch 23:
#   Train Loss: 1.1876 | Train Acc: 0.5312 | Train F1: 0.5123
#   Val   Loss: 1.1440 | Val   Acc: 0.3508 | Val   F1: 0.3424
# EarlyStopping counter: 2 out of 10
# Epoch 24:
#   Train Loss: 1.1772 | Train Acc: 0.5302 | Train F1: 0.5066
#   Val   Loss: 1.1479 | Val   Acc: 0.3455 | Val   F1: 0.3413
# EarlyStopping counter: 3 out of 10
# Epoch 25:
#   Train Loss: 1.1662 | Train Acc: 0.5561 | Train F1: 0.5436
#   Val   Loss: 1.1459 | Val   Acc: 0.3403 | Val   F1: 0.3326
# EarlyStopping counter: 4 out of 10
# Epoch 26:
#   Train Loss: 1.1583 | Train Acc: 0.5494 | Train F1: 0.5323
#   Val   Loss: 1.1472 | Val   Acc: 0.3560 | Val   F1: 0.3535
# EarlyStopping counter: 5 out of 10
# Epoch 27:
#   Train Loss: 1.1473 | Train Acc: 0.5484 | Train F1: 0.5350
#   Val   Loss: 1.1454 | Val   Acc: 0.3508 | Val   F1: 0.3464
# EarlyStopping counter: 6 out of 10
# Epoch 28:
#   Train Loss: 1.1362 | Train Acc: 0.5666 | Train F1: 0.5552
#   Val   Loss: 1.1442 | Val   Acc: 0.3560 | Val   F1: 0.3494
# EarlyStopping counter: 7 out of 10
# Epoch 29:
#   Train Loss: 1.1258 | Train Acc: 0.5695 | Train F1: 0.5598
#   Val   Loss: 1.1465 | Val   Acc: 0.3613 | Val   F1: 0.3583
# EarlyStopping counter: 8 out of 10
# Epoch 30:
#   Train Loss: 1.1154 | Train Acc: 0.5743 | Train F1: 0.5644
#   Val   Loss: 1.1459 | Val   Acc: 0.3613 | Val   F1: 0.3549
# EarlyStopping counter: 9 out of 10
# Epoch 31:
#   Train Loss: 1.1056 | Train Acc: 0.5772 | Train F1: 0.5681
#   Val   Loss: 1.1424 | Val   Acc: 0.3717 | Val   F1: 0.3671
# Epoch 32:
#   Train Loss: 1.0959 | Train Acc: 0.5935 | Train F1: 0.5859
#   Val   Loss: 1.1486 | Val   Acc: 0.3613 | Val   F1: 0.3564
# EarlyStopping counter: 1 out of 10
# Epoch 33:
#   Train Loss: 1.0856 | Train Acc: 0.5964 | Train F1: 0.5848
#   Val   Loss: 1.1399 | Val   Acc: 0.3979 | Val   F1: 0.3950
# Epoch 34:
#   Train Loss: 1.0787 | Train Acc: 0.5964 | Train F1: 0.5926
#   Val   Loss: 1.1331 | Val   Acc: 0.4084 | Val   F1: 0.4021
# Epoch 35:
#   Train Loss: 1.0670 | Train Acc: 0.6098 | Train F1: 0.6040
#   Val   Loss: 1.1364 | Val   Acc: 0.4031 | Val   F1: 0.3987
# EarlyStopping counter: 1 out of 10
# Epoch 36:
#   Train Loss: 1.0555 | Train Acc: 0.6203 | Train F1: 0.6136
#   Val   Loss: 1.1383 | Val   Acc: 0.4084 | Val   F1: 0.4060
# Epoch 37:
#   Train Loss: 1.0469 | Train Acc: 0.6184 | Train F1: 0.6144
#   Val   Loss: 1.1398 | Val   Acc: 0.3979 | Val   F1: 0.3931
# EarlyStopping counter: 1 out of 10
# Epoch 38:
#   Train Loss: 1.0371 | Train Acc: 0.6309 | Train F1: 0.6257
#   Val   Loss: 1.1449 | Val   Acc: 0.4084 | Val   F1: 0.4060
# EarlyStopping counter: 2 out of 10
# Epoch 39:
#   Train Loss: 1.0287 | Train Acc: 0.6366 | Train F1: 0.6321
#   Val   Loss: 1.1423 | Val   Acc: 0.4084 | Val   F1: 0.4054
# EarlyStopping counter: 3 out of 10
# Epoch 40:
#   Train Loss: 1.0192 | Train Acc: 0.6424 | Train F1: 0.6368
#   Val   Loss: 1.1403 | Val   Acc: 0.4136 | Val   F1: 0.4109
# Epoch 41:
#   Train Loss: 1.0101 | Train Acc: 0.6529 | Train F1: 0.6481
#   Val   Loss: 1.1321 | Val   Acc: 0.4241 | Val   F1: 0.4198
# Epoch 42:
#   Train Loss: 1.0012 | Train Acc: 0.6539 | Train F1: 0.6490
#   Val   Loss: 1.1400 | Val   Acc: 0.4293 | Val   F1: 0.4274
# Epoch 43:
#   Train Loss: 0.9895 | Train Acc: 0.6635 | Train F1: 0.6594
#   Val   Loss: 1.1326 | Val   Acc: 0.4450 | Val   F1: 0.4420
# Epoch 44:
#   Train Loss: 0.9812 | Train Acc: 0.6807 | Train F1: 0.6761
#   Val   Loss: 1.1240 | Val   Acc: 0.4450 | Val   F1: 0.4405
# EarlyStopping counter: 1 out of 10
# Epoch 45:
#   Train Loss: 0.9705 | Train Acc: 0.6798 | Train F1: 0.6761
#   Val   Loss: 1.1270 | Val   Acc: 0.4346 | Val   F1: 0.4325
# EarlyStopping counter: 2 out of 10
# Epoch 46:
#   Train Loss: 0.9592 | Train Acc: 0.6865 | Train F1: 0.6844
#   Val   Loss: 1.1254 | Val   Acc: 0.4398 | Val   F1: 0.4373
# EarlyStopping counter: 3 out of 10
# Epoch 47:
#   Train Loss: 0.9494 | Train Acc: 0.6903 | Train F1: 0.6861
#   Val   Loss: 1.1238 | Val   Acc: 0.4398 | Val   F1: 0.4363
# EarlyStopping counter: 4 out of 10
# Epoch 48:
#   Train Loss: 0.9447 | Train Acc: 0.6903 | Train F1: 0.6872
#   Val   Loss: 1.1347 | Val   Acc: 0.4555 | Val   F1: 0.4545
# Epoch 49:
#   Train Loss: 0.9322 | Train Acc: 0.7066 | Train F1: 0.7023
#   Val   Loss: 1.1171 | Val   Acc: 0.4660 | Val   F1: 0.4618
# Epoch 50:
#   Train Loss: 0.9268 | Train Acc: 0.7105 | Train F1: 0.7074
#   Val   Loss: 1.1160 | Val   Acc: 0.4712 | Val   F1: 0.4667
# Epoch 51:
#   Train Loss: 0.9164 | Train Acc: 0.7191 | Train F1: 0.7157
#   Val   Loss: 1.1162 | Val   Acc: 0.4764 | Val   F1: 0.4697
# Epoch 52:
#   Train Loss: 0.9046 | Train Acc: 0.7287 | Train F1: 0.7258
#   Val   Loss: 1.1085 | Val   Acc: 0.4817 | Val   F1: 0.4771
# Epoch 53:
#   Train Loss: 0.8981 | Train Acc: 0.7191 | Train F1: 0.7174
#   Val   Loss: 1.1171 | Val   Acc: 0.4869 | Val   F1: 0.4849
# Epoch 54:
#   Train Loss: 0.8879 | Train Acc: 0.7402 | Train F1: 0.7374
#   Val   Loss: 1.0997 | Val   Acc: 0.4974 | Val   F1: 0.4894
# Epoch 55:
#   Train Loss: 0.8802 | Train Acc: 0.7536 | Train F1: 0.7519
#   Val   Loss: 1.1097 | Val   Acc: 0.4764 | Val   F1: 0.4714
# EarlyStopping counter: 1 out of 10
# Epoch 56:
#   Train Loss: 0.8713 | Train Acc: 0.7498 | Train F1: 0.7473
#   Val   Loss: 1.1056 | Val   Acc: 0.5026 | Val   F1: 0.4993
# Epoch 57:
#   Train Loss: 0.8599 | Train Acc: 0.7584 | Train F1: 0.7567
#   Val   Loss: 1.1190 | Val   Acc: 0.4817 | Val   F1: 0.4805
# EarlyStopping counter: 1 out of 10
# Epoch 58:
#   Train Loss: 0.8534 | Train Acc: 0.7593 | Train F1: 0.7575
#   Val   Loss: 1.1026 | Val   Acc: 0.4974 | Val   F1: 0.4934
# EarlyStopping counter: 2 out of 10
# Epoch 59:
#   Train Loss: 0.8414 | Train Acc: 0.7718 | Train F1: 0.7698
#   Val   Loss: 1.0981 | Val   Acc: 0.4974 | Val   F1: 0.4939
# EarlyStopping counter: 3 out of 10
# Epoch 60:
#   Train Loss: 0.8334 | Train Acc: 0.7747 | Train F1: 0.7726
#   Val   Loss: 1.0984 | Val   Acc: 0.5026 | Val   F1: 0.4988
# EarlyStopping counter: 4 out of 10
# Epoch 61:
#   Train Loss: 0.8257 | Train Acc: 0.7766 | Train F1: 0.7745
#   Val   Loss: 1.0859 | Val   Acc: 0.5183 | Val   F1: 0.5110
# Epoch 62:
#   Train Loss: 0.8192 | Train Acc: 0.7862 | Train F1: 0.7848
#   Val   Loss: 1.0945 | Val   Acc: 0.5079 | Val   F1: 0.5011
# EarlyStopping counter: 1 out of 10
# Epoch 63:
#   Train Loss: 0.8105 | Train Acc: 0.7824 | Train F1: 0.7808
#   Val   Loss: 1.1002 | Val   Acc: 0.5131 | Val   F1: 0.5098
# EarlyStopping counter: 2 out of 10
# Epoch 64:
#   Train Loss: 0.8046 | Train Acc: 0.7833 | Train F1: 0.7813
#   Val   Loss: 1.0793 | Val   Acc: 0.5288 | Val   F1: 0.5208
# Epoch 65:
#   Train Loss: 0.8007 | Train Acc: 0.7872 | Train F1: 0.7855
#   Val   Loss: 1.0867 | Val   Acc: 0.5236 | Val   F1: 0.5154
# EarlyStopping counter: 1 out of 10
# Epoch 66:
#   Train Loss: 0.7884 | Train Acc: 0.7958 | Train F1: 0.7943
#   Val   Loss: 1.0889 | Val   Acc: 0.5183 | Val   F1: 0.5096
# EarlyStopping counter: 2 out of 10
# Epoch 67:
#   Train Loss: 0.7818 | Train Acc: 0.7919 | Train F1: 0.7898
#   Val   Loss: 1.0992 | Val   Acc: 0.5079 | Val   F1: 0.5036
# EarlyStopping counter: 3 out of 10
# Epoch 68:
#   Train Loss: 0.7742 | Train Acc: 0.8015 | Train F1: 0.8004
#   Val   Loss: 1.1018 | Val   Acc: 0.5131 | Val   F1: 0.5059
# EarlyStopping counter: 4 out of 10
# Epoch 69:
#   Train Loss: 0.7701 | Train Acc: 0.8092 | Train F1: 0.8074
#   Val   Loss: 1.0914 | Val   Acc: 0.5340 | Val   F1: 0.5251
# Epoch 70:
#   Train Loss: 0.7637 | Train Acc: 0.8035 | Train F1: 0.8016
#   Val   Loss: 1.1044 | Val   Acc: 0.5131 | Val   F1: 0.5073
# EarlyStopping counter: 1 out of 10
# Epoch 71:
#   Train Loss: 0.7565 | Train Acc: 0.7996 | Train F1: 0.7983
#   Val   Loss: 1.0962 | Val   Acc: 0.5236 | Val   F1: 0.5169
# EarlyStopping counter: 2 out of 10
# Epoch 72:
#   Train Loss: 0.7480 | Train Acc: 0.8207 | Train F1: 0.8194
#   Val   Loss: 1.0948 | Val   Acc: 0.5026 | Val   F1: 0.4974
# EarlyStopping counter: 3 out of 10
# Epoch 73:
#   Train Loss: 0.7413 | Train Acc: 0.8293 | Train F1: 0.8282
#   Val   Loss: 1.0848 | Val   Acc: 0.5288 | Val   F1: 0.5153
# EarlyStopping counter: 4 out of 10
# Epoch 74:
#   Train Loss: 0.7351 | Train Acc: 0.8207 | Train F1: 0.8193
#   Val   Loss: 1.0796 | Val   Acc: 0.5183 | Val   F1: 0.5085
# EarlyStopping counter: 5 out of 10
# Epoch 75:
#   Train Loss: 0.7294 | Train Acc: 0.8303 | Train F1: 0.8289
#   Val   Loss: 1.0873 | Val   Acc: 0.5288 | Val   F1: 0.5215
# EarlyStopping counter: 6 out of 10
# Epoch 76:
#   Train Loss: 0.7216 | Train Acc: 0.8293 | Train F1: 0.8278
#   Val   Loss: 1.0855 | Val   Acc: 0.5340 | Val   F1: 0.5213
# EarlyStopping counter: 7 out of 10
# Epoch 77:
#   Train Loss: 0.7138 | Train Acc: 0.8408 | Train F1: 0.8399
#   Val   Loss: 1.0855 | Val   Acc: 0.5340 | Val   F1: 0.5205
# EarlyStopping counter: 8 out of 10
# Epoch 78:
#   Train Loss: 0.7078 | Train Acc: 0.8370 | Train F1: 0.8357
#   Val   Loss: 1.1159 | Val   Acc: 0.5288 | Val   F1: 0.5252
# Epoch 79:
#   Train Loss: 0.7029 | Train Acc: 0.8447 | Train F1: 0.8433
#   Val   Loss: 1.0879 | Val   Acc: 0.5131 | Val   F1: 0.5037
# EarlyStopping counter: 1 out of 10
# Epoch 80:
#   Train Loss: 0.6975 | Train Acc: 0.8476 | Train F1: 0.8461
#   Val   Loss: 1.0815 | Val   Acc: 0.5340 | Val   F1: 0.5232
# EarlyStopping counter: 2 out of 10
# Epoch 81:
#   Train Loss: 0.6951 | Train Acc: 0.8485 | Train F1: 0.8479
#   Val   Loss: 1.0841 | Val   Acc: 0.5288 | Val   F1: 0.5171
# EarlyStopping counter: 3 out of 10
# Epoch 82:
#   Train Loss: 0.6831 | Train Acc: 0.8562 | Train F1: 0.8553
#   Val   Loss: 1.0820 | Val   Acc: 0.5288 | Val   F1: 0.5191
# EarlyStopping counter: 4 out of 10
# Epoch 83:
#   Train Loss: 0.6779 | Train Acc: 0.8495 | Train F1: 0.8485
#   Val   Loss: 1.1046 | Val   Acc: 0.5288 | Val   F1: 0.5209
# EarlyStopping counter: 5 out of 10
# Epoch 84:
#   Train Loss: 0.6734 | Train Acc: 0.8552 | Train F1: 0.8543
#   Val   Loss: 1.0885 | Val   Acc: 0.5131 | Val   F1: 0.5047
# EarlyStopping counter: 6 out of 10
# Epoch 85:
#   Train Loss: 0.6674 | Train Acc: 0.8667 | Train F1: 0.8657
#   Val   Loss: 1.0878 | Val   Acc: 0.5183 | Val   F1: 0.5090
# EarlyStopping counter: 7 out of 10
# Epoch 86:
#   Train Loss: 0.6590 | Train Acc: 0.8706 | Train F1: 0.8695
#   Val   Loss: 1.0894 | Val   Acc: 0.5393 | Val   F1: 0.5295
# Epoch 87:
#   Train Loss: 0.6551 | Train Acc: 0.8754 | Train F1: 0.8745
#   Val   Loss: 1.1008 | Val   Acc: 0.5445 | Val   F1: 0.5361
# Epoch 88:
#   Train Loss: 0.6515 | Train Acc: 0.8821 | Train F1: 0.8814
#   Val   Loss: 1.0905 | Val   Acc: 0.5340 | Val   F1: 0.5275
# EarlyStopping counter: 1 out of 10
# Epoch 89:
#   Train Loss: 0.6425 | Train Acc: 0.8840 | Train F1: 0.8834
#   Val   Loss: 1.1077 | Val   Acc: 0.5445 | Val   F1: 0.5380
# Epoch 90:
#   Train Loss: 0.6378 | Train Acc: 0.8830 | Train F1: 0.8824
#   Val   Loss: 1.1054 | Val   Acc: 0.5340 | Val   F1: 0.5342
# EarlyStopping counter: 1 out of 10
# Epoch 91:
#   Train Loss: 0.6394 | Train Acc: 0.8849 | Train F1: 0.8846
#   Val   Loss: 1.1037 | Val   Acc: 0.5288 | Val   F1: 0.5216
# EarlyStopping counter: 2 out of 10
# Epoch 92:
#   Train Loss: 0.6306 | Train Acc: 0.8888 | Train F1: 0.8880
#   Val   Loss: 1.0908 | Val   Acc: 0.5236 | Val   F1: 0.5128
# EarlyStopping counter: 3 out of 10
# Epoch 93:
#   Train Loss: 0.6238 | Train Acc: 0.8974 | Train F1: 0.8972
#   Val   Loss: 1.1001 | Val   Acc: 0.5236 | Val   F1: 0.5173
# EarlyStopping counter: 4 out of 10
# Epoch 94:
#   Train Loss: 0.6208 | Train Acc: 0.8993 | Train F1: 0.8990
#   Val   Loss: 1.1056 | Val   Acc: 0.5236 | Val   F1: 0.5168
# EarlyStopping counter: 5 out of 10
# Epoch 95:
#   Train Loss: 0.6158 | Train Acc: 0.9012 | Train F1: 0.9010
#   Val   Loss: 1.1065 | Val   Acc: 0.5393 | Val   F1: 0.5266
# EarlyStopping counter: 6 out of 10
# Epoch 96:
#   Train Loss: 0.6075 | Train Acc: 0.9041 | Train F1: 0.9040
#   Val   Loss: 1.0998 | Val   Acc: 0.5445 | Val   F1: 0.5416
# Epoch 97:
#   Train Loss: 0.6054 | Train Acc: 0.9080 | Train F1: 0.9076
#   Val   Loss: 1.1079 | Val   Acc: 0.5236 | Val   F1: 0.5136
# EarlyStopping counter: 1 out of 10
# Epoch 98:
#   Train Loss: 0.6001 | Train Acc: 0.9099 | Train F1: 0.9094
#   Val   Loss: 1.1075 | Val   Acc: 0.5393 | Val   F1: 0.5340
# EarlyStopping counter: 2 out of 10
# Epoch 99:
#   Train Loss: 0.5930 | Train Acc: 0.9051 | Train F1: 0.9047
#   Val   Loss: 1.1101 | Val   Acc: 0.5393 | Val   F1: 0.5262
# EarlyStopping counter: 3 out of 10
# Epoch 100:
#   Train Loss: 0.5891 | Train Acc: 0.9137 | Train F1: 0.9135
#   Val   Loss: 1.1136 | Val   Acc: 0.5393 | Val   F1: 0.5284
# EarlyStopping counter: 4 out of 10
# Epoch 101:
#   Train Loss: 0.5854 | Train Acc: 0.9156 | Train F1: 0.9154
#   Val   Loss: 1.1258 | Val   Acc: 0.5497 | Val   F1: 0.5343
# EarlyStopping counter: 5 out of 10
# Epoch 102:
#   Train Loss: 0.5851 | Train Acc: 0.9128 | Train F1: 0.9122
#   Val   Loss: 1.1195 | Val   Acc: 0.5393 | Val   F1: 0.5340
# EarlyStopping counter: 6 out of 10
# Epoch 103:
#   Train Loss: 0.5759 | Train Acc: 0.9175 | Train F1: 0.9174
#   Val   Loss: 1.1160 | Val   Acc: 0.5445 | Val   F1: 0.5380
# EarlyStopping counter: 7 out of 10
# Epoch 104:
#   Train Loss: 0.5694 | Train Acc: 0.9185 | Train F1: 0.9183
#   Val   Loss: 1.1191 | Val   Acc: 0.5602 | Val   F1: 0.5534
# Epoch 105:
#   Train Loss: 0.5650 | Train Acc: 0.9243 | Train F1: 0.9241
#   Val   Loss: 1.1169 | Val   Acc: 0.5497 | Val   F1: 0.5434
# EarlyStopping counter: 1 out of 10
# Epoch 106:
#   Train Loss: 0.5601 | Train Acc: 0.9262 | Train F1: 0.9260
#   Val   Loss: 1.1217 | Val   Acc: 0.5707 | Val   F1: 0.5633
# Epoch 107:
#   Train Loss: 0.5551 | Train Acc: 0.9319 | Train F1: 0.9318
#   Val   Loss: 1.1174 | Val   Acc: 0.5864 | Val   F1: 0.5814
# Epoch 108:
#   Train Loss: 0.5516 | Train Acc: 0.9348 | Train F1: 0.9348
#   Val   Loss: 1.1243 | Val   Acc: 0.5654 | Val   F1: 0.5591
# EarlyStopping counter: 1 out of 10
# Epoch 109:
#   Train Loss: 0.5473 | Train Acc: 0.9348 | Train F1: 0.9347
#   Val   Loss: 1.1322 | Val   Acc: 0.5707 | Val   F1: 0.5624
# EarlyStopping counter: 2 out of 10
# Epoch 110:
#   Train Loss: 0.5445 | Train Acc: 0.9406 | Train F1: 0.9405
#   Val   Loss: 1.1225 | Val   Acc: 0.5864 | Val   F1: 0.5800
# EarlyStopping counter: 3 out of 10
# Epoch 111:
#   Train Loss: 0.5424 | Train Acc: 0.9367 | Train F1: 0.9367
#   Val   Loss: 1.1227 | Val   Acc: 0.5812 | Val   F1: 0.5791
# EarlyStopping counter: 4 out of 10
# Epoch 112:
#   Train Loss: 0.5350 | Train Acc: 0.9444 | Train F1: 0.9444
#   Val   Loss: 1.1298 | Val   Acc: 0.5602 | Val   F1: 0.5545
# EarlyStopping counter: 5 out of 10
# Epoch 113:
#   Train Loss: 0.5312 | Train Acc: 0.9415 | Train F1: 0.9415
#   Val   Loss: 1.1281 | Val   Acc: 0.5969 | Val   F1: 0.5908
# Epoch 114:
#   Train Loss: 0.5271 | Train Acc: 0.9463 | Train F1: 0.9463
#   Val   Loss: 1.1395 | Val   Acc: 0.5602 | Val   F1: 0.5559
# EarlyStopping counter: 1 out of 10
# Epoch 115:
#   Train Loss: 0.5262 | Train Acc: 0.9396 | Train F1: 0.9395
#   Val   Loss: 1.1346 | Val   Acc: 0.5969 | Val   F1: 0.5881
# EarlyStopping counter: 2 out of 10
# Epoch 116:
#   Train Loss: 0.5209 | Train Acc: 0.9482 | Train F1: 0.9482
#   Val   Loss: 1.1404 | Val   Acc: 0.5759 | Val   F1: 0.5674
# EarlyStopping counter: 3 out of 10
# Epoch 117:
#   Train Loss: 0.5190 | Train Acc: 0.9492 | Train F1: 0.9492
#   Val   Loss: 1.1450 | Val   Acc: 0.5602 | Val   F1: 0.5559
# EarlyStopping counter: 4 out of 10
# Epoch 118:
#   Train Loss: 0.5149 | Train Acc: 0.9482 | Train F1: 0.9482
#   Val   Loss: 1.1447 | Val   Acc: 0.5759 | Val   F1: 0.5729
# EarlyStopping counter: 5 out of 10
# Epoch 119:
#   Train Loss: 0.5088 | Train Acc: 0.9530 | Train F1: 0.9529
#   Val   Loss: 1.1447 | Val   Acc: 0.5812 | Val   F1: 0.5776
# EarlyStopping counter: 6 out of 10
# Epoch 120:
#   Train Loss: 0.5038 | Train Acc: 0.9569 | Train F1: 0.9568
#   Val   Loss: 1.1411 | Val   Acc: 0.5864 | Val   F1: 0.5813
# EarlyStopping counter: 7 out of 10
# Epoch 121:
#   Train Loss: 0.5037 | Train Acc: 0.9559 | Train F1: 0.9557
#   Val   Loss: 1.1530 | Val   Acc: 0.5812 | Val   F1: 0.5745
# EarlyStopping counter: 8 out of 10
# Epoch 122:
#   Train Loss: 0.5003 | Train Acc: 0.9549 | Train F1: 0.9549
#   Val   Loss: 1.1475 | Val   Acc: 0.5759 | Val   F1: 0.5723
# EarlyStopping counter: 9 out of 10
# Epoch 123:
#   Train Loss: 0.4979 | Train Acc: 0.9540 | Train F1: 0.9541
#   Val   Loss: 1.1542 | Val   Acc: 0.5812 | Val   F1: 0.5767
# EarlyStopping counter: 10 out of 10
# Early stopping triggered!
# Finished training with lr=1e-05, weight_decay=0.01, Best Val F1=0.5908
#
# >>> Trying lr=1e-05, weight_decay=0.05
# Epoch 1:
#   Train Loss: 1.3860 | Train Acc: 0.2359 | Train F1: 0.1595
#   Val   Loss: 1.1872 | Val   Acc: 0.2199 | Val   F1: 0.1430
# Epoch 2:
#   Train Loss: 1.3841 | Train Acc: 0.2780 | Train F1: 0.1903
#   Val   Loss: 1.1873 | Val   Acc: 0.2408 | Val   F1: 0.1665
# Epoch 3:
#   Train Loss: 1.3822 | Train Acc: 0.3030 | Train F1: 0.2319
#   Val   Loss: 1.1877 | Val   Acc: 0.2618 | Val   F1: 0.1852
# Epoch 4:
#   Train Loss: 1.3802 | Train Acc: 0.3423 | Train F1: 0.2783
#   Val   Loss: 1.1872 | Val   Acc: 0.2880 | Val   F1: 0.2385
# Epoch 5:
#   Train Loss: 1.3776 | Train Acc: 0.3682 | Train F1: 0.2989
#   Val   Loss: 1.1868 | Val   Acc: 0.2880 | Val   F1: 0.2301
# EarlyStopping counter: 1 out of 10
# Epoch 6:
#   Train Loss: 1.3744 | Train Acc: 0.3720 | Train F1: 0.2921
#   Val   Loss: 1.1861 | Val   Acc: 0.3089 | Val   F1: 0.2473
# Epoch 7:
#   Train Loss: 1.3700 | Train Acc: 0.3864 | Train F1: 0.3021
#   Val   Loss: 1.1836 | Val   Acc: 0.3141 | Val   F1: 0.2593
# Epoch 8:
#   Train Loss: 1.3639 | Train Acc: 0.3998 | Train F1: 0.3223
#   Val   Loss: 1.1799 | Val   Acc: 0.3246 | Val   F1: 0.2659
# Epoch 9:
#   Train Loss: 1.3549 | Train Acc: 0.4199 | Train F1: 0.3425
#   Val   Loss: 1.1731 | Val   Acc: 0.3351 | Val   F1: 0.2846
# Epoch 10:
#   Train Loss: 1.3424 | Train Acc: 0.4487 | Train F1: 0.3807
#   Val   Loss: 1.1654 | Val   Acc: 0.3298 | Val   F1: 0.2984
# Epoch 11:
#   Train Loss: 1.3269 | Train Acc: 0.4391 | Train F1: 0.3655
#   Val   Loss: 1.1574 | Val   Acc: 0.3246 | Val   F1: 0.2879
# EarlyStopping counter: 1 out of 10
# Epoch 12:
#   Train Loss: 1.3104 | Train Acc: 0.4439 | Train F1: 0.3682
#   Val   Loss: 1.1488 | Val   Acc: 0.3298 | Val   F1: 0.3033
# Epoch 13:
#   Train Loss: 1.2916 | Train Acc: 0.4736 | Train F1: 0.4101
#   Val   Loss: 1.1374 | Val   Acc: 0.3403 | Val   F1: 0.3018
# EarlyStopping counter: 1 out of 10
# Epoch 14:
#   Train Loss: 1.2732 | Train Acc: 0.4842 | Train F1: 0.4311
#   Val   Loss: 1.1314 | Val   Acc: 0.3560 | Val   F1: 0.3324
# Epoch 15:
#   Train Loss: 1.2555 | Train Acc: 0.4890 | Train F1: 0.4363
#   Val   Loss: 1.1228 | Val   Acc: 0.3613 | Val   F1: 0.3415
# Epoch 16:
#   Train Loss: 1.2393 | Train Acc: 0.4890 | Train F1: 0.4306
#   Val   Loss: 1.1189 | Val   Acc: 0.3822 | Val   F1: 0.3628
# Epoch 17:
#   Train Loss: 1.2247 | Train Acc: 0.5168 | Train F1: 0.4877
#   Val   Loss: 1.1102 | Val   Acc: 0.3874 | Val   F1: 0.3760
# Epoch 18:
#   Train Loss: 1.2098 | Train Acc: 0.5244 | Train F1: 0.4943
#   Val   Loss: 1.1084 | Val   Acc: 0.3822 | Val   F1: 0.3718
# EarlyStopping counter: 1 out of 10
# Epoch 19:
#   Train Loss: 1.1951 | Train Acc: 0.5321 | Train F1: 0.5052
#   Val   Loss: 1.1085 | Val   Acc: 0.3770 | Val   F1: 0.3616
# EarlyStopping counter: 2 out of 10
# Epoch 20:
#   Train Loss: 1.1814 | Train Acc: 0.5388 | Train F1: 0.5113
#   Val   Loss: 1.0997 | Val   Acc: 0.3927 | Val   F1: 0.3864
# Epoch 21:
#   Train Loss: 1.1695 | Train Acc: 0.5513 | Train F1: 0.5342
#   Val   Loss: 1.0920 | Val   Acc: 0.4031 | Val   F1: 0.3953
# Epoch 22:
#   Train Loss: 1.1574 | Train Acc: 0.5580 | Train F1: 0.5435
#   Val   Loss: 1.0987 | Val   Acc: 0.4188 | Val   F1: 0.4125
# Epoch 23:
#   Train Loss: 1.1447 | Train Acc: 0.5695 | Train F1: 0.5528
#   Val   Loss: 1.0928 | Val   Acc: 0.4136 | Val   F1: 0.4054
# EarlyStopping counter: 1 out of 10
# Epoch 24:
#   Train Loss: 1.1329 | Train Acc: 0.5762 | Train F1: 0.5653
#   Val   Loss: 1.0987 | Val   Acc: 0.3979 | Val   F1: 0.3935
# EarlyStopping counter: 2 out of 10
# Epoch 25:
#   Train Loss: 1.1191 | Train Acc: 0.5935 | Train F1: 0.5814
#   Val   Loss: 1.0916 | Val   Acc: 0.4136 | Val   F1: 0.4062
# EarlyStopping counter: 3 out of 10
# Epoch 26:
#   Train Loss: 1.1088 | Train Acc: 0.5925 | Train F1: 0.5824
#   Val   Loss: 1.0830 | Val   Acc: 0.4293 | Val   F1: 0.4231
# Epoch 27:
#   Train Loss: 1.0974 | Train Acc: 0.6002 | Train F1: 0.5914
#   Val   Loss: 1.0903 | Val   Acc: 0.4241 | Val   F1: 0.4183
# EarlyStopping counter: 1 out of 10
# Epoch 28:
#   Train Loss: 1.0893 | Train Acc: 0.6079 | Train F1: 0.5989
#   Val   Loss: 1.0796 | Val   Acc: 0.4346 | Val   F1: 0.4277
# Epoch 29:
#   Train Loss: 1.0778 | Train Acc: 0.6203 | Train F1: 0.6095
#   Val   Loss: 1.0878 | Val   Acc: 0.4293 | Val   F1: 0.4247
# EarlyStopping counter: 1 out of 10
# Epoch 30:
#   Train Loss: 1.0663 | Train Acc: 0.6261 | Train F1: 0.6198
#   Val   Loss: 1.0816 | Val   Acc: 0.4503 | Val   F1: 0.4492
# Epoch 31:
#   Train Loss: 1.0564 | Train Acc: 0.6376 | Train F1: 0.6297
#   Val   Loss: 1.0763 | Val   Acc: 0.4660 | Val   F1: 0.4587
# Epoch 32:
#   Train Loss: 1.0464 | Train Acc: 0.6472 | Train F1: 0.6403
#   Val   Loss: 1.0753 | Val   Acc: 0.4555 | Val   F1: 0.4512
# EarlyStopping counter: 1 out of 10
# Epoch 33:
#   Train Loss: 1.0375 | Train Acc: 0.6395 | Train F1: 0.6312
#   Val   Loss: 1.0651 | Val   Acc: 0.4817 | Val   F1: 0.4798
# Epoch 34:
#   Train Loss: 1.0293 | Train Acc: 0.6529 | Train F1: 0.6469
#   Val   Loss: 1.0831 | Val   Acc: 0.4555 | Val   F1: 0.4553
# EarlyStopping counter: 1 out of 10
# Epoch 35:
#   Train Loss: 1.0204 | Train Acc: 0.6577 | Train F1: 0.6508
#   Val   Loss: 1.0772 | Val   Acc: 0.4607 | Val   F1: 0.4602
# EarlyStopping counter: 2 out of 10
# Epoch 36:
#   Train Loss: 1.0114 | Train Acc: 0.6673 | Train F1: 0.6582
#   Val   Loss: 1.0607 | Val   Acc: 0.4712 | Val   F1: 0.4664
# EarlyStopping counter: 3 out of 10
# Epoch 37:
#   Train Loss: 1.0004 | Train Acc: 0.6711 | Train F1: 0.6658
#   Val   Loss: 1.0596 | Val   Acc: 0.4712 | Val   F1: 0.4689
# EarlyStopping counter: 4 out of 10
# Epoch 38:
#   Train Loss: 0.9914 | Train Acc: 0.6779 | Train F1: 0.6714
#   Val   Loss: 1.0722 | Val   Acc: 0.4607 | Val   F1: 0.4570
# EarlyStopping counter: 5 out of 10
# Epoch 39:
#   Train Loss: 0.9855 | Train Acc: 0.6798 | Train F1: 0.6760
#   Val   Loss: 1.0706 | Val   Acc: 0.4764 | Val   F1: 0.4760
# EarlyStopping counter: 6 out of 10
# Epoch 40:
#   Train Loss: 0.9756 | Train Acc: 0.6836 | Train F1: 0.6764
#   Val   Loss: 1.0544 | Val   Acc: 0.4869 | Val   F1: 0.4873
# Epoch 41:
#   Train Loss: 0.9669 | Train Acc: 0.6951 | Train F1: 0.6899
#   Val   Loss: 1.0706 | Val   Acc: 0.4712 | Val   F1: 0.4704
# EarlyStopping counter: 1 out of 10
# Epoch 42:
#   Train Loss: 0.9622 | Train Acc: 0.6970 | Train F1: 0.6883
#   Val   Loss: 1.0505 | Val   Acc: 0.4817 | Val   F1: 0.4758
# EarlyStopping counter: 2 out of 10
# Epoch 43:
#   Train Loss: 0.9505 | Train Acc: 0.7085 | Train F1: 0.7040
#   Val   Loss: 1.0858 | Val   Acc: 0.4921 | Val   F1: 0.4868
# EarlyStopping counter: 3 out of 10
# Epoch 44:
#   Train Loss: 0.9458 | Train Acc: 0.7009 | Train F1: 0.6958
#   Val   Loss: 1.0624 | Val   Acc: 0.4869 | Val   F1: 0.4824
# EarlyStopping counter: 4 out of 10
# Epoch 45:
#   Train Loss: 0.9383 | Train Acc: 0.7066 | Train F1: 0.6990
#   Val   Loss: 1.0525 | Val   Acc: 0.4921 | Val   F1: 0.4892
# Epoch 46:
#   Train Loss: 0.9297 | Train Acc: 0.7076 | Train F1: 0.6990
#   Val   Loss: 1.0466 | Val   Acc: 0.5026 | Val   F1: 0.4975
# Epoch 47:
#   Train Loss: 0.9210 | Train Acc: 0.7239 | Train F1: 0.7188
#   Val   Loss: 1.0515 | Val   Acc: 0.4817 | Val   F1: 0.4806
# EarlyStopping counter: 1 out of 10
# Epoch 48:
#   Train Loss: 0.9142 | Train Acc: 0.7325 | Train F1: 0.7273
#   Val   Loss: 1.0651 | Val   Acc: 0.5079 | Val   F1: 0.5024
# Epoch 49:
#   Train Loss: 0.9058 | Train Acc: 0.7306 | Train F1: 0.7258
#   Val   Loss: 1.0450 | Val   Acc: 0.5026 | Val   F1: 0.4976
# EarlyStopping counter: 1 out of 10
# Epoch 50:
#   Train Loss: 0.8995 | Train Acc: 0.7383 | Train F1: 0.7333
#   Val   Loss: 1.0441 | Val   Acc: 0.5026 | Val   F1: 0.4980
# EarlyStopping counter: 2 out of 10
# Epoch 51:
#   Train Loss: 0.8915 | Train Acc: 0.7354 | Train F1: 0.7290
#   Val   Loss: 1.0527 | Val   Acc: 0.5079 | Val   F1: 0.5036
# Epoch 52:
#   Train Loss: 0.8842 | Train Acc: 0.7430 | Train F1: 0.7387
#   Val   Loss: 1.0391 | Val   Acc: 0.5183 | Val   F1: 0.5118
# Epoch 53:
#   Train Loss: 0.8784 | Train Acc: 0.7430 | Train F1: 0.7379
#   Val   Loss: 1.0507 | Val   Acc: 0.5026 | Val   F1: 0.4979
# EarlyStopping counter: 1 out of 10
# Epoch 54:
#   Train Loss: 0.8711 | Train Acc: 0.7440 | Train F1: 0.7390
#   Val   Loss: 1.0559 | Val   Acc: 0.5131 | Val   F1: 0.5103
# EarlyStopping counter: 2 out of 10
# Epoch 55:
#   Train Loss: 0.8643 | Train Acc: 0.7478 | Train F1: 0.7429
#   Val   Loss: 1.0375 | Val   Acc: 0.5236 | Val   F1: 0.5186
# Epoch 56:
#   Train Loss: 0.8583 | Train Acc: 0.7651 | Train F1: 0.7600
#   Val   Loss: 1.0424 | Val   Acc: 0.5236 | Val   F1: 0.5224
# Epoch 57:
#   Train Loss: 0.8541 | Train Acc: 0.7574 | Train F1: 0.7535
#   Val   Loss: 1.0416 | Val   Acc: 0.5236 | Val   F1: 0.5185
# EarlyStopping counter: 1 out of 10
# Epoch 58:
#   Train Loss: 0.8434 | Train Acc: 0.7718 | Train F1: 0.7673
#   Val   Loss: 1.0700 | Val   Acc: 0.5236 | Val   F1: 0.5161
# EarlyStopping counter: 2 out of 10
# Epoch 59:
#   Train Loss: 0.8425 | Train Acc: 0.7689 | Train F1: 0.7644
#   Val   Loss: 1.0442 | Val   Acc: 0.5079 | Val   F1: 0.4982
# EarlyStopping counter: 3 out of 10
# Epoch 60:
#   Train Loss: 0.8334 | Train Acc: 0.7728 | Train F1: 0.7689
#   Val   Loss: 1.0537 | Val   Acc: 0.5340 | Val   F1: 0.5328
# Epoch 61:
#   Train Loss: 0.8275 | Train Acc: 0.7766 | Train F1: 0.7712
#   Val   Loss: 1.0421 | Val   Acc: 0.5550 | Val   F1: 0.5506
# Epoch 62:
#   Train Loss: 0.8227 | Train Acc: 0.7709 | Train F1: 0.7661
#   Val   Loss: 1.0373 | Val   Acc: 0.5236 | Val   F1: 0.5167
# EarlyStopping counter: 1 out of 10
# Epoch 63:
#   Train Loss: 0.8188 | Train Acc: 0.7766 | Train F1: 0.7738
#   Val   Loss: 1.0318 | Val   Acc: 0.5602 | Val   F1: 0.5558
# Epoch 64:
#   Train Loss: 0.8111 | Train Acc: 0.7919 | Train F1: 0.7873
#   Val   Loss: 1.0656 | Val   Acc: 0.5340 | Val   F1: 0.5310
# EarlyStopping counter: 1 out of 10
# Epoch 65:
#   Train Loss: 0.8059 | Train Acc: 0.7939 | Train F1: 0.7912
#   Val   Loss: 1.0616 | Val   Acc: 0.5236 | Val   F1: 0.5166
# EarlyStopping counter: 2 out of 10
# Epoch 66:
#   Train Loss: 0.8004 | Train Acc: 0.7919 | Train F1: 0.7887
#   Val   Loss: 1.0433 | Val   Acc: 0.5497 | Val   F1: 0.5479
# EarlyStopping counter: 3 out of 10
# Epoch 67:
#   Train Loss: 0.7970 | Train Acc: 0.7900 | Train F1: 0.7860
#   Val   Loss: 1.0389 | Val   Acc: 0.5393 | Val   F1: 0.5340
# EarlyStopping counter: 4 out of 10
# Epoch 68:
#   Train Loss: 0.7922 | Train Acc: 0.7795 | Train F1: 0.7747
#   Val   Loss: 1.0407 | Val   Acc: 0.5602 | Val   F1: 0.5575
# Epoch 69:
#   Train Loss: 0.7843 | Train Acc: 0.7939 | Train F1: 0.7911
#   Val   Loss: 1.0562 | Val   Acc: 0.5445 | Val   F1: 0.5387
# EarlyStopping counter: 1 out of 10
# Epoch 70:
#   Train Loss: 0.7790 | Train Acc: 0.8015 | Train F1: 0.7978
#   Val   Loss: 1.0345 | Val   Acc: 0.5550 | Val   F1: 0.5516
# EarlyStopping counter: 2 out of 10
# Epoch 71:
#   Train Loss: 0.7752 | Train Acc: 0.7987 | Train F1: 0.7943
#   Val   Loss: 1.0377 | Val   Acc: 0.5602 | Val   F1: 0.5577
# Epoch 72:
#   Train Loss: 0.7699 | Train Acc: 0.8188 | Train F1: 0.8167
#   Val   Loss: 1.0369 | Val   Acc: 0.5707 | Val   F1: 0.5704
# Epoch 73:
#   Train Loss: 0.7631 | Train Acc: 0.8102 | Train F1: 0.8069
#   Val   Loss: 1.0382 | Val   Acc: 0.5654 | Val   F1: 0.5646
# EarlyStopping counter: 1 out of 10
# Epoch 74:
#   Train Loss: 0.7604 | Train Acc: 0.8198 | Train F1: 0.8173
#   Val   Loss: 1.0730 | Val   Acc: 0.5288 | Val   F1: 0.5223
# EarlyStopping counter: 2 out of 10
# Epoch 75:
#   Train Loss: 0.7555 | Train Acc: 0.8140 | Train F1: 0.8116
#   Val   Loss: 1.0694 | Val   Acc: 0.5393 | Val   F1: 0.5350
# EarlyStopping counter: 3 out of 10
# Epoch 76:
#   Train Loss: 0.7550 | Train Acc: 0.8102 | Train F1: 0.8071
#   Val   Loss: 1.0433 | Val   Acc: 0.5602 | Val   F1: 0.5570
# EarlyStopping counter: 4 out of 10
# Epoch 77:
#   Train Loss: 0.7501 | Train Acc: 0.8178 | Train F1: 0.8155
#   Val   Loss: 1.0314 | Val   Acc: 0.5707 | Val   F1: 0.5639
# EarlyStopping counter: 5 out of 10
# Epoch 78:
#   Train Loss: 0.7434 | Train Acc: 0.8255 | Train F1: 0.8238
#   Val   Loss: 1.0623 | Val   Acc: 0.5550 | Val   F1: 0.5514
# EarlyStopping counter: 6 out of 10
# Epoch 79:
#   Train Loss: 0.7363 | Train Acc: 0.8284 | Train F1: 0.8262
#   Val   Loss: 1.0781 | Val   Acc: 0.5393 | Val   F1: 0.5380
# EarlyStopping counter: 7 out of 10
# Epoch 80:
#   Train Loss: 0.7318 | Train Acc: 0.8389 | Train F1: 0.8380
#   Val   Loss: 1.0500 | Val   Acc: 0.5654 | Val   F1: 0.5641
# EarlyStopping counter: 8 out of 10
# Epoch 81:
#   Train Loss: 0.7275 | Train Acc: 0.8351 | Train F1: 0.8327
#   Val   Loss: 1.0702 | Val   Acc: 0.5497 | Val   F1: 0.5501
# EarlyStopping counter: 9 out of 10
# Epoch 82:
#   Train Loss: 0.7240 | Train Acc: 0.8399 | Train F1: 0.8378
#   Val   Loss: 1.0607 | Val   Acc: 0.5550 | Val   F1: 0.5522
# EarlyStopping counter: 10 out of 10
# Early stopping triggered!
# Finished training with lr=1e-05, weight_decay=0.05, Best Val F1=0.5704
#
# Grid Search completed!
# Best Hyperparameters: {'lr': 5e-05, 'weight_decay': 0.05}
# Best Validation Macro-F1: 0.6575

# %% [markdown]
# ### Step 5 Test Evaluation

# %%
import torch
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix

# 1. Load the best model
model.load_state_dict(torch.load("../checkpoints/best_model_v3.pt"))  # Load the trained model weights
model.to(device)       # Move the model to the computation device (e.g., GPU or CPU)
model.eval()           # Set the model to evaluation mode

all_preds = []         # To store predicted labels
all_labels = []        # To store true labels

# 2. Run inference on the test set
with torch.no_grad():  # Disable gradient computation for faster inference
    for x, mask, edge_index, y in test_loader:
        # Move data to the device
        x = x.to(device)
        mask = mask.to(device)
        edge_index = edge_index.to(device)
        y = y.to(device)

        logits = model(x, mask, edge_index)  # Forward pass
        preds = logits.argmax(dim=-1)        # Get predicted class indices

        all_preds.extend(preds.cpu().tolist())   # Store predictions
        all_labels.extend(y.cpu().tolist())      # Store ground truth labels

# 3. Compute Accuracy and Macro F1 Score
test_acc = accuracy_score(all_labels, all_preds)
test_f1 = f1_score(all_labels, all_preds, average='macro')

print(f"Test Accuracy: {test_acc:.4f}")
print(f"Test Macro-F1: {test_f1:.4f}")

# 4. Plot Confusion Matrix
cm = confusion_matrix(all_labels, all_preds)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=True,
            xticklabels=["False", "Non-rumor", "True", "Unverified"],
            yticklabels=["False", "Non-rumor", "True", "Unverified"])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix on Test Set")
plt.tight_layout()
plt.show()
# Out:
# Test Accuracy: 0.6429
# Test Macro-F1: 0.6426
